# %%
# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
from hmmlearn import hmm
import yfinance as yf
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# ======== CONFIGURABLE PARAMETERS ========
# Market data parameters
TICKER = 'SPY'  # Main ticker to analyze
VIX_TICKER = '^VIX'  # Volatility index
START_DATE = "2000-01-01"  # Historical data start date

# HMM model parameters  
HIDDEN_STATES = 3  # Number of market regimes
EM_ITERATIONS = 100  # Training iterations for HMM

# High-pass filter parameters
HPF_WINDOW = 21  # Window size for the high-pass filter moving average

# Training period
TRAIN_START_DATE = "2019-01-01"
TRAIN_END_DATE = "2024-01-01"

# Rolling window parameters
TRAINING_DELAY = 5  # Number of days to wait before retraining the model
USE_EXPANDING_WINDOW = True  # If True, use expanding window; if False, use fixed window

# ======== DATA PREPARATION FUNCTIONS ========
def download_market_data(ticker, vix_ticker, start_date):
    """Download and prepare market data"""
    end_date = datetime.today().strftime("%Y-%m-%d")
    print(f"Downloading market data from {start_date} to {end_date}...")
    
    # Download ticker and VIX data
    df_ticker = yf.download(ticker, start=start_date, end=end_date, auto_adjust=True)
    df_vix = yf.download(vix_ticker, start=start_date, end=end_date)
    
    # Fix column structure and reset index
    if len(df_ticker.columns.names) > 1:
        df_ticker.columns = df_ticker.columns.droplevel(1)
    if len(df_vix.columns.names) > 1:
        df_vix.columns = df_vix.columns.droplevel(1)
    
    df_ticker = df_ticker.reset_index()
    df_vix = df_vix.reset_index()
    
    # Keep only Date and Close from VIX
    df_vix = df_vix[['Date', 'Close']].rename(columns={'Close': 'VIX'})
    
    # Merge data
    df = pd.merge(df_ticker, df_vix, on='Date', how='left')
    df['VIX'] = df['VIX'].fillna(method='ffill')
    df['LogVIX'] = np.log(df['VIX'])
    
    return df

def calculate_indicators(data):
    """Calculate technical indicators for regime classification"""
    df_copy = data.copy()
    
    # Calculate returns
    df_copy['Return'] = df_copy['Close'].pct_change() * 100
    
    # Calculate volatility (10-day window)
    df_copy['MA10'] = df_copy['Close'].rolling(window=10).mean()
    df_copy['Volatility'] = df_copy['Close'].rolling(window=10).apply(
        lambda x: np.sum((x - x.mean())**2) / len(x)
    )
    
    # LogVIX ratio compared to 10-day average
    df_copy['LogVIX_10MA'] = df_copy['LogVIX'].rolling(window=10).mean()
    df_copy['LogVIX_Ratio'] = df_copy['LogVIX'] / df_copy['LogVIX_10MA']
    
    # Forward fill and backward fill any NaNs
    df_copy = df_copy.fillna(method='ffill').fillna(method='bfill')
    
    return df_copy

def apply_high_pass_filter(data, window_size=10):
    """
    Apply high-pass filter by subtracting moving average 
    from original signal to emphasize significant market movements
    """
    filtered_data = data.copy()
    
    # Apply HPF to returns
    filtered_data['Return_MA'] = filtered_data['Return'].rolling(window=window_size).mean()
    filtered_data['HPF_Return'] = filtered_data['Return'] - filtered_data['Return_MA']
    
    # Apply HPF to LogVIX
    filtered_data['LogVIX_MA'] = filtered_data['LogVIX'].rolling(window=window_size).mean()
    filtered_data['HPF_LogVIX'] = filtered_data['LogVIX'] - filtered_data['LogVIX_MA']
    
    # Apply HPF to volatility
    filtered_data['Volatility_MA'] = filtered_data['Volatility'].rolling(window=window_size).mean()
    filtered_data['HPF_Volatility'] = filtered_data['Volatility'] - filtered_data['Volatility_MA']
    
    # Fill any NaNs created by rolling windows
    filtered_data = filtered_data.fillna(method='ffill').fillna(method='bfill')
    
    return filtered_data

# ======== HMM MODEL FUNCTIONS ========
def train_hmm_model(data, start_date, end_date, n_states=3, n_iter=75):
    """Train HMM model on high-pass filtered features"""
    # Filter data to training period
    training = data[(data['Date'] >= start_date) & (data['Date'] <= end_date)].copy()
    
    print(f"Training HMM model on data from {start_date} to {end_date}")
    print(f"Training data shape: {training.shape}")
    
    # Prepare observations for HMM using HPF features
    obs = np.column_stack([
        training['HPF_Volatility'].values, 
        training['HPF_Return'].values,
        training['HPF_LogVIX'].values
    ])
    
    # Create and train the model
    model = hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=n_iter)
    model.fit(obs)
    
    # Get predictions for training data
    predictions = model.predict(obs)
    
    # Analyze regime characteristics using original (non-HPF) data for interpretability
    regime_stats = {}
    for i in range(n_states):
        regime_mask = (predictions == i)
        if np.sum(regime_mask) > 0:
            regime_stats[i] = {
                'count': np.sum(regime_mask),
                'return_avg': np.mean(training.loc[regime_mask, 'Return']),
                'vix_avg': np.mean(training.loc[regime_mask, 'VIX']),
                'logvix_avg': np.mean(training.loc[regime_mask, 'LogVIX']),
                'volatility_avg': np.mean(training.loc[regime_mask, 'Volatility'])
            }
    
    # Assign labels to regimes (Bull, Bear, Neutral) based on characteristics
    regime_labels = [""] * n_states
    bull_scores = []
    bear_scores = []
    neutral_scores = []
    
    for i in range(n_states):
        if i not in regime_stats:
            bull_scores.append(0)
            bear_scores.append(0)
            neutral_scores.append(0)
            continue
            
        stats = regime_stats[i]
        
        # Bull regime scoring: high returns, lower VIX
        bull_score = 0
        if stats['return_avg'] > 0.05:
            bull_score += 2
        elif stats['return_avg'] > 0:
            bull_score += 1
        
        if stats['logvix_avg'] < 2.8:  # Log(16.5) ≈ 2.8
            bull_score += 2
        elif stats['logvix_avg'] < 3.0:  # Log(20) ≈ 3.0
            bull_score += 1
        
        # Bear regime scoring: negative returns, higher VIX
        bear_score = 0
        if stats['return_avg'] < -0.1:
            bear_score += 2
        elif stats['return_avg'] < 0:
            bear_score += 1
        
        if stats['logvix_avg'] > 3.2:  # Log(25) ≈ 3.2
            bear_score += 2
        elif stats['logvix_avg'] > 3.0:
            bear_score += 1
        
        # Neutral regime scoring: modest returns, moderate VIX
        neutral_score = 0
        if -0.05 < stats['return_avg'] < 0.05:
            neutral_score += 2
        elif -0.1 < stats['return_avg'] < 0.1:
            neutral_score += 1
        
        if 2.8 <= stats['logvix_avg'] <= 3.2:
            neutral_score += 2
        elif 2.7 <= stats['logvix_avg'] <= 3.3:
            neutral_score += 1
        
        bull_scores.append(bull_score)
        bear_scores.append(bear_score)
        neutral_scores.append(neutral_score)
    
    # Assign labels based on highest score
    labels_to_assign = ["Bull", "Bear", "Neutral"]
    scores = [(i, max(bull_scores[i], bear_scores[i], neutral_scores[i]), 
               "Bull" if bull_scores[i] >= max(bear_scores[i], neutral_scores[i]) else
               "Bear" if bear_scores[i] >= max(bull_scores[i], neutral_scores[i]) else
               "Neutral") 
              for i in range(n_states)]
    
    # Sort by score and assign labels ensuring each label is used only once
    scores.sort(key=lambda x: x[1], reverse=True)
    assigned_labels = set()
    
    for regime_idx, _, preferred_label in scores:
        if preferred_label not in assigned_labels:
            regime_labels[regime_idx] = preferred_label
            assigned_labels.add(preferred_label)
        else:
            # Find an unassigned label
            for label in labels_to_assign:
                if label not in assigned_labels:
                    regime_labels[regime_idx] = label
                    assigned_labels.add(label)
                    break
    
    # Print key regime statistics
    print("\nRegime Characteristics Summary:")
    print("=" * 60)
    print(f"{'Regime':<10} {'Label':<8} {'Count':<8} {'Return %':<10} {'VIX':<8} {'LogVIX':<8}")
    print("-" * 60)
    
    for i in range(n_states):
        if i in regime_stats:
            stats = regime_stats[i]
            print(f"{i:<10} {regime_labels[i]:<8} {stats['count']:<8} "
                  f"{stats['return_avg']:<10.2f} {stats['vix_avg']:<8.2f} {stats['logvix_avg']:<8.2f}")
    
    # Print transition matrix
    print("\nRegime Transition Matrix:")
    transition_matrix = model.transmat_
    
    print("=" * 60)
    print(f"{'From/To':<10}", end="")
    for i in range(n_states):
        print(f"{regime_labels[i]:<10}", end="")
    print()
    print("-" * 60)
    
    for i in range(n_states):
        print(f"{regime_labels[i]:<10}", end="")
        for j in range(n_states):
            print(f"{transition_matrix[i, j]:<10.2f}", end="")
        print()
    
    # Calculate stationary distribution
    stationary_dist = model.get_stationary_distribution()
    print("\nStationary Distribution (Long-term regime probabilities):")
    for i in range(n_states):
        print(f"Regime {i} [{regime_labels[i]}]: {stationary_dist[i]*100:.2f}%")
    
    return model, training, predictions, regime_labels, regime_stats

def predict_regimes(model, data, start_date, end_date, regime_labels):
    """Predict market regimes for a specific date range using the trained HMM model"""
    # Filter data for prediction period
    pred_data = data[(data['Date'] >= start_date) & (data['Date'] <= end_date)].copy()
    
    if len(pred_data) == 0:
        print(f"No data available for period {start_date} to {end_date}")
        return None
    
    # Prepare observations for prediction using HPF features
    obs = np.column_stack([
        pred_data['HPF_Volatility'].values, 
        pred_data['HPF_Return'].values,
        pred_data['HPF_LogVIX'].values
    ])
    
    # Predict regimes
    predictions = model.predict(obs)
    
    # Add predictions to dataframe
    pred_data['Predicted_Regime'] = predictions
    pred_data['Regime_Label'] = [regime_labels[r] for r in predictions]
    
    # Print basic statistics about the prediction
    print(f"Predicted regimes for period {start_date} to {end_date}")
    
    # Calculate regime distribution
    regime_counts = pd.Series(predictions).value_counts(normalize=True) * 100
    print("\nRegime Distribution:")
    for regime, percentage in regime_counts.items():
        print(f"Regime {regime} [{regime_labels[regime]}]: {percentage:.2f}%")
    
    # Calculate average regime duration
    regime_changes = (pred_data['Predicted_Regime'] != pred_data['Predicted_Regime'].shift(1)).sum()
    avg_duration = len(pred_data) / (regime_changes if regime_changes > 0 else 1)
    print(f"\nRegime persistence: {avg_duration:.2f} days average duration")
    
    return pred_data

# ======== VISUALIZATION FUNCTIONS ========
def plot_regimes(results, title=None):
    """Plot SPY price with regime classifications"""
    if results is None or len(results) == 0:
        print("No data available to plot")
        return
    
    # Set plot title
    if title is None:
        start_date = results['Date'].min().strftime('%Y-%m-%d')
        end_date = results['Date'].max().strftime('%Y-%m-%d')
        title = f'Market Regimes from {start_date} to {end_date}'
    
    # Create a categorical color map for regimes
    unique_regimes = results['Predicted_Regime'].unique()
    n_regimes = len(unique_regimes)
    regime_colors = px.colors.qualitative.Set2[:n_regimes]
    
    # Create figure
    fig = go.Figure()
    
    # Add price line
    fig.add_trace(
        go.Scatter(
            x=results['Date'],
            y=results['Close'],
            mode='lines',
            line=dict(color='rgba(0,0,0,0.3)', width=1),
            name=f'{TICKER} Price'
        )
    )
    
    # Add colored markers for different regimes
    for i, regime in enumerate(sorted(unique_regimes)):
        regime_data = results[results['Predicted_Regime'] == regime]
        regime_label = results.loc[results['Predicted_Regime'] == regime, 'Regime_Label'].iloc[0]
        
        fig.add_trace(
            go.Scatter(
                x=regime_data['Date'], 
                y=regime_data['Close'],
                mode='markers',
                marker=dict(color=regime_colors[i], size=6),
                name=f'{regime_label} Regime',
                hovertemplate='%{x}<br>Price: %{y:.2f}<br>Regime: ' + regime_label
            )
        )
    
    # Update layout
    fig.update_layout(
        title=title,
        xaxis_title='Date',
        yaxis_title=f'{TICKER} Price',
        template='plotly_white',
        legend_title='Market Regimes',
        hovermode='closest',
        height=600
    )
    
    fig.show()
    
    # Create pie chart showing regime distribution
    regime_distribution = results['Regime_Label'].value_counts().reset_index()
    regime_distribution.columns = ['Regime', 'Days']
    regime_distribution['Percentage'] = regime_distribution['Days'] / len(results) * 100
    
    fig_pie = px.pie(
        regime_distribution, 
        values='Percentage', 
        names='Regime',
        title=f'Regime Distribution ({results["Date"].min().strftime("%Y-%m-%d")} to {results["Date"].max().strftime("%Y-%m-%d")})',
        color_discrete_sequence=regime_colors
    )
    
    fig_pie.update_traces(textinfo='percent+label', textposition='inside')
    fig_pie.update_layout(uniformtext_minsize=12, uniformtext_mode='hide')
    
    fig_pie.show()

# ======== ROLLING WINDOW FUNCTIONS ========
def run_rolling_window_simulation(df, initial_train_start, initial_train_end, 
                                 final_eval_date=None, training_delay=5, 
                                 use_expanding_window=True, n_states=3, n_iter=75):
    """
    Run a realistic rolling window simulation where the model is retrained periodically.
    
    Parameters:
    - df: DataFrame containing all market data
    - initial_train_start: Initial training period start date
    - initial_train_end: Initial training period end date
    - final_eval_date: Last date to evaluate (defaults to last date in dataset)
    - training_delay: Number of days to wait before retraining the model
    - use_expanding_window: If True, use expanding window; if False, use fixed window
    - n_states: Number of hidden states for HMM
    - n_iter: Number of EM iterations for HMM
    
    Returns:
    - DataFrame with regime predictions for the entire period
    """
    print(f"Running rolling window simulation with retraining every {training_delay} days")
    print(f"Using {'expanding' if use_expanding_window else 'fixed'} window approach")
    
    if final_eval_date is None:
        final_eval_date = df['Date'].max().strftime('%Y-%m-%d')
    
    # Convert dates to datetime objects for easier manipulation
    initial_train_start_dt = pd.to_datetime(initial_train_start)
    initial_train_end_dt = pd.to_datetime(initial_train_end)
    final_eval_date_dt = pd.to_datetime(final_eval_date)
    
    # Initialize the first model with the initial training period
    print(f"\n===== Initial Model Training: {initial_train_start} to {initial_train_end} =====")
    model, _, _, regime_labels, _ = train_hmm_model(
        df, initial_train_start, initial_train_end, n_states, n_iter
    )
    
    # Initialize variables to track our progress
    current_date = initial_train_end_dt
    next_retrain_date = current_date + timedelta(days=training_delay)
    current_train_start = initial_train_start_dt if use_expanding_window else initial_train_start_dt
    current_train_end = initial_train_end_dt
    
    # Create a results dataframe to store all predictions
    all_results = []
    
    # Variables to track retraining events
    retrain_dates = [initial_train_end_dt]
    
    # Sort dates for sequential processing
    all_dates = sorted(df['Date'].unique())
    all_dates = [date for date in all_dates if date >= initial_train_end_dt]
    
    # Loop through dates for evaluation
    for i in range(len(all_dates) - 1):
        current_date = all_dates[i]
        next_date = all_dates[i + 1]
        
        # Only predict one day at a time (current day)
        day_results = predict_regimes(
            model, df, 
            current_date.strftime('%Y-%m-%d'), 
            current_date.strftime('%Y-%m-%d'), 
            regime_labels
        )
        
        if day_results is not None:
            all_results.append(day_results)
        
        # Check if it's time to retrain the model
        if next_date >= next_retrain_date or next_date >= final_eval_date_dt:
            # Update the training window
            if use_expanding_window:
                # Expanding window keeps the same start date, but extends the end date
                current_train_end = current_date
            else:
                # Fixed window slides both start and end date
                window_size = (initial_train_end_dt - initial_train_start_dt).days
                current_train_start = current_date - timedelta(days=window_size)
                current_train_end = current_date
            
            print(f"\n===== Retraining Model: {current_train_start.strftime('%Y-%m-%d')} to {current_train_end.strftime('%Y-%m-%d')} =====")
            # Retrain the model
            model, _, _, regime_labels, _ = train_hmm_model(
                df, 
                current_train_start.strftime('%Y-%m-%d'), 
                current_train_end.strftime('%Y-%m-%d'), 
                n_states, n_iter
            )
            
            # Set the next retrain date
            next_retrain_date = next_date + timedelta(days=training_delay)
            retrain_dates.append(current_date)
        
        # Break the loop if we've reached the final evaluation date
        if current_date >= final_eval_date_dt:
            break
    
    # Combine all results
    if all_results:
        combined_results = pd.concat(all_results, ignore_index=True)
        combined_results = combined_results.sort_values('Date')
        
        # Create additional column to indicate model retraining dates
        combined_results['Retrain_Event'] = combined_results['Date'].isin(retrain_dates)
        
        print(f"\n===== Rolling Window Simulation Complete =====")
        print(f"Evaluated period: {combined_results['Date'].min().strftime('%Y-%m-%d')} to {combined_results['Date'].max().strftime('%Y-%m-%d')}")
        print(f"Total days evaluated: {len(combined_results)}")
        print(f"Number of model retrainings: {len(retrain_dates) - 1}")  # Subtract 1 for initial training
        
        return combined_results
    else:
        print("No results generated during simulation.")
        return None

def plot_rolling_window_results(results):
    """Plot the results of a rolling window simulation, highlighting retraining events"""
    if results is None or len(results) == 0:
        print("No data available to plot")
        return
    
    # Create a categorical color map for regimes
    unique_regimes = results['Predicted_Regime'].unique()
    n_regimes = len(unique_regimes)
    regime_colors = px.colors.qualitative.Set2[:n_regimes]
    
    # Create figure
    fig = go.Figure()
    
    # Add price line
    fig.add_trace(
        go.Scatter(
            x=results['Date'],
            y=results['Close'],
            mode='lines',
            line=dict(color='rgba(0,0,0,0.3)', width=1),
            name=f'{TICKER} Price'
        )
    )
    
    # Add colored markers for different regimes
    for i, regime in enumerate(sorted(unique_regimes)):
        regime_data = results[results['Predicted_Regime'] == regime]
        regime_label = results.loc[results['Predicted_Regime'] == regime, 'Regime_Label'].iloc[0]
        
        fig.add_trace(
            go.Scatter(
                x=regime_data['Date'], 
                y=regime_data['Close'],
                mode='markers',
                marker=dict(color=regime_colors[i], size=6),
                name=f'{regime_label} Regime',
                hovertemplate='%{x}<br>Price: %{y:.2f}<br>Regime: ' + regime_label
            )
        )
    
    # Add vertical lines for retraining events
    retrain_dates = results[results['Retrain_Event']]['Date'].unique()
    for date in retrain_dates:
        # Convert date to string format to avoid Timestamp arithmetic issues
        fig.add_vline(x=date.strftime('%Y-%m-%d'), line_width=1, line_dash="dash", line_color="red",
                      annotation_text="Retrain", annotation_position="top right")
    
    # Update layout
    fig.update_layout(
        title=f'Rolling Window Regime Predictions ({results["Date"].min().strftime("%Y-%m-%d")} to {results["Date"].max().strftime("%Y-%m-%d")})',
        xaxis_title='Date',
        yaxis_title=f'{TICKER} Price',
        template='plotly_white',
        legend_title='Market Regimes',
        hovermode='closest',
        height=600
    )
    
    fig.show()
    
    # Create regime distribution by month or week
    results['YearMonth'] = results['Date'].dt.strftime('%Y-%m')
    monthly_regimes = results.groupby(['YearMonth', 'Regime_Label']).size().unstack().fillna(0)
    
    # Convert to percentages
    monthly_total = monthly_regimes.sum(axis=1)
    monthly_pct = monthly_regimes.div(monthly_total, axis=0) * 100
    
    # Plot monthly regime distribution
    fig_monthly = px.bar(
        monthly_pct.reset_index().melt(id_vars='YearMonth', var_name='Regime', value_name='Percentage'),
        x='YearMonth',
        y='Percentage',
        color='Regime',
        color_discrete_sequence=regime_colors,
        title='Monthly Regime Distribution',
        barmode='stack'
    )
    
    fig_monthly.update_layout(
        xaxis_title='Month',
        yaxis_title='Percentage (%)',
        legend_title='Regime',
        hovermode='x unified'
    )
    
    fig_monthly.show()

# ======== MAIN EXECUTION ========
def main():
    # Download and prepare data
    df = download_market_data(TICKER, VIX_TICKER, START_DATE)
    df = calculate_indicators(df)
    df = apply_high_pass_filter(df, HPF_WINDOW)
    
    # Train initial model
    model, training_data, train_predictions, regime_labels, regime_stats = train_hmm_model(
        df, TRAIN_START_DATE, TRAIN_END_DATE, HIDDEN_STATES, EM_ITERATIONS
    )
    
    # Plot training period results
    training_results = training_data.copy()
    training_results['Predicted_Regime'] = train_predictions
    training_results['Regime_Label'] = [regime_labels[r] for r in train_predictions]
    
    print("\nVisualization of training period regimes:")
    plot_regimes(training_results, f'Market Regimes - Training Period ({TRAIN_START_DATE} to {TRAIN_END_DATE})')
    
    # Run rolling window simulation
    rolling_results = run_rolling_window_simulation(
        df, 
        TRAIN_START_DATE, 
        TRAIN_END_DATE, 
        None,  # Use all available data
        TRAINING_DELAY,
        USE_EXPANDING_WINDOW,
        HIDDEN_STATES, 
        EM_ITERATIONS
    )
    
    # Plot rolling window results
    if rolling_results is not None:
        plot_rolling_window_results(rolling_results)
    
    return {
        'model': model,
        'data': df,
        'regime_labels': regime_labels,
        'training_results': training_results,
        'rolling_results': rolling_results
    }

# Function to analyze any time period
def analyze_period(model_objects, start_date, end_date, title=None):
    """Analyze any time period using the trained model"""
    results = predict_regimes(
        model_objects['model'], 
        model_objects['data'], 
        start_date, 
        end_date, 
        model_objects['regime_labels']
    )
    
    if results is not None:
        plot_regimes(results, title)
    
    return results

# Execute main function
if __name__ == "__main__":
    model_objects = main()
    
    # Example 
    # To analyze a custom period, uncomment and modify:
    # custom_results = analyze_period(model_objects, "2008-01-01", "2009-12-31", "Market Regimes - 2008 Financial Crisis")
# Out:
# Downloading market data from 2000-01-01 to 2025-04-13...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# YF.download() has changed argument auto_adjust default to True
# Training HMM model on data from 2019-01-01 to 2024-01-01
# Training data shape: (1258, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     796      0.14       18.30    2.88
# 1          Neutral  272      -0.01      23.01    3.11
# 2          Bear     190      -0.13      31.85    3.39
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Neutral   Bear
# ------------------------------------------------------------
# Bull      0.95      0.05      0.01
# Neutral   0.11      0.87      0.02
# Bear      0.06      0.00      0.94
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 62.37%
# Regime 1 [Neutral]: 22.20%
# Regime 2 [Bear]: 15.43%
#
# Visualization of training period regimes:
# Running rolling window simulation with retraining every 5 days
# Using expanding window approach
#
# ===== Initial Model Training: 2019-01-01 to 2024-01-01 =====
# Training HMM model on data from 2019-01-01 to 2024-01-01
# Training data shape: (1258, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Neutral  595      0.05       18.37    2.88
# 1          Bull     408      0.23       19.55    2.94
# 2          Bear     255      -0.15      31.26    3.39
#
# Regime Transition Matrix:
# ============================================================
# From/To   Neutral   Bull      Bear
# ------------------------------------------------------------
# Neutral   0.94      0.02      0.03
# Bull      0.05      0.94      0.01
# Bear      0.05      0.04      0.91
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Neutral]: 47.40%
# Regime 1 [Bull]: 31.95%
# Regime 2 [Bear]: 20.65%
# Predicted regimes for period 2024-01-02 to 2024-01-02
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-01-03 to 2024-01-03
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-01-04 to 2024-01-04
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-01-05 to 2024-01-05
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-01-05 =====
# Training HMM model on data from 2019-01-01 to 2024-01-05
# Training data shape: (1262, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     564      0.23       17.59    2.84
# 1          Bear     180      -0.11      32.22    3.41
# 2          Neutral  518      -0.05      21.65    3.04
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.93      0.01      0.06
# Bear      0.03      0.91      0.06
# Neutral   0.07      0.03      0.90
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 44.93%
# Regime 1 [Bear]: 14.59%
# Regime 2 [Neutral]: 40.48%
# Predicted regimes for period 2024-01-08 to 2024-01-08
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-01-09 to 2024-01-09
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-01-10 to 2024-01-10
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-01-11 to 2024-01-11
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-01-12 to 2024-01-12
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-01-12 =====
# Training HMM model on data from 2019-01-01 to 2024-01-12
# Training data shape: (1267, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Neutral  607      0.05       18.32    2.88
# 1          Bear     255      -0.15      31.26    3.39
# 2          Bull     405      0.23       19.53    2.94
#
# Regime Transition Matrix:
# ============================================================
# From/To   Neutral   Bear      Bull
# ------------------------------------------------------------
# Neutral   0.94      0.03      0.02
# Bear      0.05      0.91      0.04
# Bull      0.05      0.01      0.94
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Neutral]: 47.68%
# Regime 1 [Bear]: 20.57%
# Regime 2 [Bull]: 31.75%
# Predicted regimes for period 2024-01-16 to 2024-01-16
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-01-17 to 2024-01-17
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-01-18 to 2024-01-18
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-01-19 to 2024-01-19
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-01-19 =====
# Training HMM model on data from 2019-01-01 to 2024-01-19
# Training data shape: (1271, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     408      0.23       19.55    2.94
# 1          Bear     255      -0.15      31.26    3.39
# 2          Neutral  608      0.05       18.27    2.88
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.94      0.01      0.05
# Bear      0.04      0.91      0.05
# Neutral   0.02      0.03      0.94
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 31.71%
# Regime 1 [Bear]: 20.50%
# Regime 2 [Neutral]: 47.79%
# Predicted regimes for period 2024-01-22 to 2024-01-22
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-01-23 to 2024-01-23
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-01-24 to 2024-01-24
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-01-25 to 2024-01-25
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-01-26 to 2024-01-26
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-01-26 =====
# Training HMM model on data from 2019-01-01 to 2024-01-26
# Training data shape: (1276, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     408      0.23       19.55    2.94
# 1          Bear     255      -0.15      31.26    3.39
# 2          Neutral  613      0.05       18.23    2.87
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.94      0.01      0.05
# Bear      0.04      0.91      0.05
# Neutral   0.02      0.03      0.94
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 31.60%
# Regime 1 [Bear]: 20.47%
# Regime 2 [Neutral]: 47.93%
# Predicted regimes for period 2024-01-29 to 2024-01-29
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-01-30 to 2024-01-30
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-01-31 to 2024-01-31
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-02-01 to 2024-02-01
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-02-02 to 2024-02-02
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-02-02 =====
# Training HMM model on data from 2019-01-01 to 2024-02-02
# Training data shape: (1281, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     618      0.05       18.19    2.87
# 1          Neutral  408      0.23       19.55    2.94
# 2          Bear     255      -0.15      31.26    3.39
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Neutral   Bear
# ------------------------------------------------------------
# Bull      0.94      0.02      0.03
# Neutral   0.05      0.94      0.01
# Bear      0.05      0.04      0.91
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 48.13%
# Regime 1 [Neutral]: 31.50%
# Regime 2 [Bear]: 20.37%
# Predicted regimes for period 2024-02-05 to 2024-02-05
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-02-06 to 2024-02-06
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-02-07 to 2024-02-07
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-02-08 to 2024-02-08
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-02-09 to 2024-02-09
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-02-09 =====
# Training HMM model on data from 2019-01-01 to 2024-02-09
# Training data shape: (1286, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     820      0.15       18.17    2.87
# 1          Bear     190      -0.13      31.85    3.39
# 2          Neutral  276      -0.03      22.83    3.10
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.95      0.01      0.05
# Bear      0.06      0.94      0.00
# Neutral   0.12      0.02      0.87
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 62.99%
# Regime 1 [Bear]: 15.19%
# Regime 2 [Neutral]: 21.82%
# Predicted regimes for period 2024-02-12 to 2024-02-12
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-02-13 to 2024-02-13
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-02-14 to 2024-02-14
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-02-15 to 2024-02-15
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-02-16 to 2024-02-16
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-02-16 =====
# Training HMM model on data from 2019-01-01 to 2024-02-16
# Training data shape: (1291, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     495      0.05       18.60    2.89
# 1          Bear     323      -0.11      29.07    3.31
# 2          Neutral  473      0.21       18.46    2.89
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.22      0.05      0.73
# Bear      0.00      0.92      0.08
# Neutral   0.99      0.01      0.00
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 41.88%
# Regime 1 [Bear]: 25.36%
# Regime 2 [Neutral]: 32.76%
# Predicted regimes for period 2024-02-20 to 2024-02-20
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-02-21 to 2024-02-21
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-02-22 to 2024-02-22
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-02-23 to 2024-02-23
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-02-23 =====
# Training HMM model on data from 2019-01-01 to 2024-02-23
# Training data shape: (1295, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     408      0.23       19.55    2.94
# 1          Bear     255      -0.15      31.26    3.39
# 2          Neutral  632      0.06       18.10    2.87
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.94      0.01      0.05
# Bear      0.04      0.91      0.05
# Neutral   0.02      0.03      0.95
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 31.25%
# Regime 1 [Bear]: 20.19%
# Regime 2 [Neutral]: 48.57%
# Predicted regimes for period 2024-02-26 to 2024-02-26
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-02-27 to 2024-02-27
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-02-28 to 2024-02-28
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-02-29 to 2024-02-29
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-03-01 to 2024-03-01
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-03-01 =====
# Training HMM model on data from 2019-01-01 to 2024-03-01
# Training data shape: (1300, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Neutral  262      -0.02      22.94    3.10
# 1          Bull     848      0.14       18.15    2.87
# 2          Bear     190      -0.13      31.85    3.39
#
# Regime Transition Matrix:
# ============================================================
# From/To   Neutral   Bull      Bear
# ------------------------------------------------------------
# Neutral   0.86      0.12      0.02
# Bull      0.05      0.95      0.01
# Bear      0.00      0.06      0.94
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Neutral]: 21.43%
# Regime 1 [Bull]: 63.51%
# Regime 2 [Bear]: 15.07%
# Predicted regimes for period 2024-03-04 to 2024-03-04
#
# Regime Distribution:
# Regime 1 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-03-05 to 2024-03-05
#
# Regime Distribution:
# Regime 1 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-03-06 to 2024-03-06
#
# Regime Distribution:
# Regime 1 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-03-07 to 2024-03-07
#
# Regime Distribution:
# Regime 1 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-03-08 to 2024-03-08
#
# Regime Distribution:
# Regime 1 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-03-08 =====
# Training HMM model on data from 2019-01-01 to 2024-03-08
# Training data shape: (1305, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     408      0.23       19.55    2.94
# 1          Bear     255      -0.15      31.26    3.39
# 2          Neutral  642      0.06       18.03    2.86
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.94      0.01      0.05
# Bear      0.04      0.91      0.06
# Neutral   0.02      0.03      0.95
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 31.01%
# Regime 1 [Bear]: 20.16%
# Regime 2 [Neutral]: 48.83%
# Predicted regimes for period 2024-03-11 to 2024-03-11
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-03-12 to 2024-03-12
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-03-13 to 2024-03-13
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-03-14 to 2024-03-14
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-03-15 to 2024-03-15
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-03-15 =====
# Training HMM model on data from 2019-01-01 to 2024-03-15
# Training data shape: (1310, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     647      0.05       18.00    2.86
# 1          Neutral  408      0.23       19.55    2.94
# 2          Bear     255      -0.15      31.26    3.39
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Neutral   Bear
# ------------------------------------------------------------
# Bull      0.95      0.02      0.03
# Neutral   0.05      0.94      0.01
# Bear      0.06      0.04      0.91
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 48.97%
# Regime 1 [Neutral]: 30.88%
# Regime 2 [Bear]: 20.15%
# Predicted regimes for period 2024-03-18 to 2024-03-18
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-03-19 to 2024-03-19
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-03-20 to 2024-03-20
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-03-21 to 2024-03-21
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-03-22 to 2024-03-22
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-03-22 =====
# Training HMM model on data from 2019-01-01 to 2024-03-22
# Training data shape: (1315, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     649      0.06       17.97    2.86
# 1          Bear     258      -0.15      31.11    3.39
# 2          Neutral  408      0.23       19.55    2.94
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.95      0.03      0.02
# Bear      0.06      0.91      0.04
# Neutral   0.05      0.01      0.94
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 49.10%
# Regime 1 [Bear]: 20.15%
# Regime 2 [Neutral]: 30.75%
# Predicted regimes for period 2024-03-25 to 2024-03-25
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-03-26 to 2024-03-26
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-03-27 to 2024-03-27
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-03-28 to 2024-03-28
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-03-28 =====
# Training HMM model on data from 2019-01-01 to 2024-03-28
# Training data shape: (1319, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     649      0.06       17.95    2.86
# 1          Bear     262      -0.14      30.88    3.38
# 2          Neutral  408      0.23       19.55    2.94
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.95      0.03      0.02
# Bear      0.06      0.91      0.04
# Neutral   0.05      0.01      0.94
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 49.24%
# Regime 1 [Bear]: 20.15%
# Regime 2 [Neutral]: 30.61%
# Predicted regimes for period 2024-04-01 to 2024-04-01
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-04-02 to 2024-04-02
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-04-03 to 2024-04-03
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-04-04 to 2024-04-04
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-04-05 to 2024-04-05
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-04-05 =====
# Training HMM model on data from 2019-01-01 to 2024-04-05
# Training data shape: (1324, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Neutral  546      0.02       18.45    2.89
# 1          Bear     323      -0.10      29.29    3.32
# 2          Bull     455      0.25       18.14    2.87
#
# Regime Transition Matrix:
# ============================================================
# From/To   Neutral   Bear      Bull
# ------------------------------------------------------------
# Neutral   0.92      0.04      0.04
# Bear      0.04      0.92      0.04
# Bull      0.07      0.02      0.92
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Neutral]: 41.67%
# Regime 1 [Bear]: 24.01%
# Regime 2 [Bull]: 34.32%
# Predicted regimes for period 2024-04-08 to 2024-04-08
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-04-09 to 2024-04-09
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-04-10 to 2024-04-10
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-04-11 to 2024-04-11
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-04-12 to 2024-04-12
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-04-12 =====
# Training HMM model on data from 2019-01-01 to 2024-04-12
# Training data shape: (1329, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     777      0.13       17.49    2.84
# 1          Bear     84       -0.12      39.66    3.62
# 2          Neutral  468      -0.00      23.39    3.12
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.96      0.00      0.04
# Bear      0.00      0.95      0.05
# Neutral   0.07      0.01      0.92
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 58.31%
# Regime 1 [Bear]: 6.43%
# Regime 2 [Neutral]: 35.26%
# Predicted regimes for period 2024-04-15 to 2024-04-15
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-04-16 to 2024-04-16
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-04-17 to 2024-04-17
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-04-18 to 2024-04-18
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-04-19 to 2024-04-19
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-04-19 =====
# Training HMM model on data from 2019-01-01 to 2024-04-19
# Training data shape: (1334, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     419      0.24       18.47    2.89
# 1          Neutral  595      0.04       18.08    2.87
# 2          Bear     320      -0.12      29.58    3.34
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Neutral   Bear
# ------------------------------------------------------------
# Bull      0.93      0.06      0.01
# Neutral   0.03      0.93      0.04
# Bear      0.04      0.04      0.92
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 31.53%
# Regime 1 [Neutral]: 43.75%
# Regime 2 [Bear]: 24.72%
# Predicted regimes for period 2024-04-22 to 2024-04-22
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-04-23 to 2024-04-23
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-04-24 to 2024-04-24
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-04-25 to 2024-04-25
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-04-26 to 2024-04-26
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-04-26 =====
# Training HMM model on data from 2019-01-01 to 2024-04-26
# Training data shape: (1339, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Neutral  610      0.05       18.02    2.86
# 1          Bear     322      -0.11      29.50    3.33
# 2          Bull     407      0.24       18.55    2.89
#
# Regime Transition Matrix:
# ============================================================
# From/To   Neutral   Bear      Bull
# ------------------------------------------------------------
# Neutral   0.93      0.04      0.03
# Bear      0.05      0.91      0.04
# Bull      0.06      0.01      0.93
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Neutral]: 44.41%
# Regime 1 [Bear]: 24.27%
# Regime 2 [Bull]: 31.31%
# Predicted regimes for period 2024-04-29 to 2024-04-29
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-04-30 to 2024-04-30
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-05-01 to 2024-05-01
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-05-02 to 2024-05-02
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-05-03 to 2024-05-03
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-05-03 =====
# Training HMM model on data from 2019-01-01 to 2024-05-03
# Training data shape: (1344, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     666      0.05       17.87    2.85
# 1          Bear     270      -0.14      30.51    3.36
# 2          Neutral  408      0.23       19.55    2.94
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.95      0.03      0.02
# Bear      0.06      0.90      0.04
# Neutral   0.05      0.01      0.94
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 49.46%
# Regime 1 [Bear]: 20.29%
# Regime 2 [Neutral]: 30.25%
# Predicted regimes for period 2024-05-06 to 2024-05-06
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-05-07 to 2024-05-07
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-05-08 to 2024-05-08
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-05-09 to 2024-05-09
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-05-10 to 2024-05-10
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-05-10 =====
# Training HMM model on data from 2019-01-01 to 2024-05-10
# Training data shape: (1349, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     665      0.05       17.88    2.85
# 1          Bear     270      -0.14      30.51    3.36
# 2          Neutral  414      0.23       19.45    2.94
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.94      0.03      0.02
# Bear      0.06      0.90      0.04
# Neutral   0.05      0.01      0.94
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 48.64%
# Regime 1 [Bear]: 20.18%
# Regime 2 [Neutral]: 31.18%
# Predicted regimes for period 2024-05-13 to 2024-05-13
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-05-14 to 2024-05-14
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-05-15 to 2024-05-15
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-05-16 to 2024-05-16
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-05-17 to 2024-05-17
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-05-17 =====
# Training HMM model on data from 2019-01-01 to 2024-05-17
# Training data shape: (1354, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     780      0.14       17.35    2.83
# 1          Neutral  491      -0.01      23.23    3.11
# 2          Bear     83       -0.13      39.85    3.63
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Neutral   Bear
# ------------------------------------------------------------
# Bull      0.96      0.04      0.00
# Neutral   0.07      0.92      0.01
# Bear      0.00      0.05      0.95
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 58.28%
# Regime 1 [Neutral]: 35.40%
# Regime 2 [Bear]: 6.32%
# Predicted regimes for period 2024-05-20 to 2024-05-20
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-05-21 to 2024-05-21
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-05-22 to 2024-05-22
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-05-23 to 2024-05-23
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-05-24 to 2024-05-24
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-05-24 =====
# Training HMM model on data from 2019-01-01 to 2024-05-24
# Training data shape: (1359, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     664      0.05       17.88    2.85
# 1          Bear     270      -0.14      30.51    3.36
# 2          Neutral  425      0.23       19.28    2.93
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.94      0.03      0.02
# Bear      0.06      0.90      0.04
# Neutral   0.05      0.01      0.94
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 48.22%
# Regime 1 [Bear]: 20.12%
# Regime 2 [Neutral]: 31.67%
# Predicted regimes for period 2024-05-28 to 2024-05-28
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-05-29 to 2024-05-29
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-05-30 to 2024-05-30
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-05-31 to 2024-05-31
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-05-31 =====
# Training HMM model on data from 2019-01-01 to 2024-05-31
# Training data shape: (1363, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     553      0.25       17.59    2.83
# 1          Neutral  529      -0.02      19.40    2.94
# 2          Bear     281      -0.13      29.80    3.33
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Neutral   Bear
# ------------------------------------------------------------
# Bull      0.92      0.07      0.01
# Neutral   0.06      0.91      0.03
# Bear      0.05      0.04      0.92
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 40.14%
# Regime 1 [Neutral]: 38.77%
# Regime 2 [Bear]: 21.10%
# Predicted regimes for period 2024-06-03 to 2024-06-03
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-06-04 to 2024-06-04
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-06-05 to 2024-06-05
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-06-06 to 2024-06-06
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-06-07 to 2024-06-07
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-06-07 =====
# Training HMM model on data from 2019-01-01 to 2024-06-07
# Training data shape: (1368, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     908      0.14       17.85    2.85
# 1          Bear     193      -0.14      31.67    3.39
# 2          Neutral  267      -0.02      22.87    3.10
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.95      0.01      0.04
# Bear      0.06      0.94      0.00
# Neutral   0.12      0.02      0.86
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 64.61%
# Regime 1 [Bear]: 14.28%
# Regime 2 [Neutral]: 21.11%
# Predicted regimes for period 2024-06-10 to 2024-06-10
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-06-11 to 2024-06-11
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-06-12 to 2024-06-12
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-06-13 to 2024-06-13
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-06-14 to 2024-06-14
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-06-14 =====
# Training HMM model on data from 2019-01-01 to 2024-06-14
# Training data shape: (1373, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     678      0.05       17.81    2.85
# 1          Bear     270      -0.14      30.51    3.36
# 2          Neutral  425      0.23       19.22    2.92
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.95      0.03      0.02
# Bear      0.06      0.90      0.04
# Neutral   0.05      0.01      0.94
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 49.32%
# Regime 1 [Bear]: 20.11%
# Regime 2 [Neutral]: 30.57%
# Predicted regimes for period 2024-06-17 to 2024-06-17
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-06-18 to 2024-06-18
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-06-20 to 2024-06-20
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-06-21 to 2024-06-21
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-06-21 =====
# Training HMM model on data from 2019-01-01 to 2024-06-21
# Training data shape: (1377, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     571      0.25       17.54    2.83
# 1          Bear     268      -0.11      29.62    3.33
# 2          Neutral  538      -0.03      19.68    2.95
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.92      0.01      0.07
# Bear      0.04      0.92      0.04
# Neutral   0.06      0.03      0.91
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 41.76%
# Regime 1 [Bear]: 20.08%
# Regime 2 [Neutral]: 38.16%
# Predicted regimes for period 2024-06-24 to 2024-06-24
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-06-25 to 2024-06-25
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-06-26 to 2024-06-26
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-06-27 to 2024-06-27
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-06-28 to 2024-06-28
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-06-28 =====
# Training HMM model on data from 2019-01-01 to 2024-06-28
# Training data shape: (1382, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Neutral  481      -0.01      23.41    3.12
# 1          Bull     818      0.14       17.15    2.82
# 2          Bear     83       -0.13      39.85    3.63
#
# Regime Transition Matrix:
# ============================================================
# From/To   Neutral   Bull      Bear
# ------------------------------------------------------------
# Neutral   0.92      0.07      0.01
# Bull      0.04      0.96      0.00
# Bear      0.05      0.00      0.95
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Neutral]: 34.63%
# Regime 1 [Bull]: 59.21%
# Regime 2 [Bear]: 6.17%
# Predicted regimes for period 2024-07-01 to 2024-07-01
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-07-02 to 2024-07-02
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-07-03 to 2024-07-03
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2024-07-05 to 2024-07-05
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2024-07-05 =====
# Training HMM model on data from 2019-01-01 to 2024-07-05
# Training data shape: (1386, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     666      0.21       17.04    2.81
# 1          Bear     196      -0.14      31.56    3.39
# 2          Neutral  524      -0.03      21.21    3.02
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.93      0.00      0.07
# Bear      0.04      0.91      0.06
# Neutral   0.08      0.03      0.90
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 47.72%
# Regime 1 [Bear]: 14.04%
# ...
# 2          Bear     685      0.14       17.23    2.82
#
# Regime Transition Matrix:
# ============================================================
# From/To   Neutral   Bull      Bear
# ------------------------------------------------------------
# Neutral   0.93      0.03      0.03
# Bull      0.04      0.85      0.11
# Bear      0.02      0.08      0.90
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Neutral]: 28.66%
# Regime 1 [Bull]: 28.47%
# Regime 2 [Bear]: 42.87%
# Predicted regimes for period 2025-03-03 to 2025-03-03
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2025-03-04 to 2025-03-04
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2025-03-05 to 2025-03-05
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2025-03-06 to 2025-03-06
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2025-03-07 to 2025-03-07
#
# Regime Distribution:
# Regime 2 [Bear]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2025-03-07 =====
# Training HMM model on data from 2019-01-01 to 2025-03-07
# Training data shape: (1554, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bear     359      -0.11      27.85    3.27
# 1          Bull     729      0.05       17.81    2.85
# 2          Neutral  466      0.23       18.47    2.88
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bear      Bull      Neutral
# ------------------------------------------------------------
# Bear      0.91      0.05      0.04
# Bull      0.04      0.94      0.02
# Neutral   0.01      0.05      0.94
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bear]: 24.04%
# Regime 1 [Bull]: 45.27%
# Regime 2 [Neutral]: 30.68%
# Predicted regimes for period 2025-03-10 to 2025-03-10
#
# Regime Distribution:
# Regime 1 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2025-03-11 to 2025-03-11
#
# Regime Distribution:
# Regime 1 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2025-03-12 to 2025-03-12
#
# Regime Distribution:
# Regime 1 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2025-03-13 to 2025-03-13
#
# Regime Distribution:
# Regime 1 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2025-03-14 to 2025-03-14
#
# Regime Distribution:
# Regime 1 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2025-03-14 =====
# Training HMM model on data from 2019-01-01 to 2025-03-14
# Training data shape: (1559, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     697      0.22       17.05    2.81
# 1          Bear     266      -0.12      28.38    3.27
# 2          Neutral  596      -0.03      20.61    2.99
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.93      0.01      0.07
# Bear      0.03      0.91      0.06
# Neutral   0.07      0.04      0.89
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 44.58%
# Regime 1 [Bear]: 17.52%
# Regime 2 [Neutral]: 37.90%
# Predicted regimes for period 2025-03-17 to 2025-03-17
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2025-03-18 to 2025-03-18
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2025-03-19 to 2025-03-19
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2025-03-20 to 2025-03-20
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2025-03-21 to 2025-03-21
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2025-03-21 =====
# Training HMM model on data from 2019-01-01 to 2025-03-21
# Training data shape: (1564, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     697      0.22       17.05    2.81
# 1          Neutral  596      -0.03      20.61    2.99
# 2          Bear     271      -0.11      28.23    3.27
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Neutral   Bear
# ------------------------------------------------------------
# Bull      0.93      0.07      0.01
# Neutral   0.07      0.89      0.04
# Bear      0.03      0.06      0.91
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 44.44%
# Regime 1 [Neutral]: 37.83%
# Regime 2 [Bear]: 17.73%
# Predicted regimes for period 2025-03-24 to 2025-03-24
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2025-03-25 to 2025-03-25
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2025-03-26 to 2025-03-26
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2025-03-27 to 2025-03-27
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2025-03-28 to 2025-03-28
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2025-03-28 =====
# Training HMM model on data from 2019-01-01 to 2025-03-28
# Training data shape: (1569, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Neutral  596      -0.03      20.61    2.99
# 1          Bull     697      0.22       17.05    2.81
# 2          Bear     276      -0.11      28.06    3.26
#
# Regime Transition Matrix:
# ============================================================
# From/To   Neutral   Bull      Bear
# ------------------------------------------------------------
# Neutral   0.89      0.07      0.04
# Bull      0.07      0.93      0.01
# Bear      0.06      0.03      0.91
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Neutral]: 37.61%
# Regime 1 [Bull]: 44.25%
# Regime 2 [Bear]: 18.14%
# Predicted regimes for period 2025-03-31 to 2025-03-31
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2025-04-01 to 2025-04-01
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2025-04-02 to 2025-04-02
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2025-04-03 to 2025-04-03
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2025-04-04 to 2025-04-04
#
# Regime Distribution:
# Regime 2 [Bear]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2025-04-04 =====
# Training HMM model on data from 2019-01-01 to 2025-04-04
# Training data shape: (1574, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bear     281      -0.15      28.06    3.26
# 1          Bull     697      0.22       17.05    2.81
# 2          Neutral  596      -0.03      20.61    2.99
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bear      Bull      Neutral
# ------------------------------------------------------------
# Bear      0.91      0.03      0.06
# Bull      0.01      0.93      0.07
# Neutral   0.04      0.07      0.89
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bear]: 18.30%
# Regime 1 [Bull]: 44.17%
# Regime 2 [Neutral]: 37.54%
# Predicted regimes for period 2025-04-07 to 2025-04-07
#
# Regime Distribution:
# Regime 0 [Bear]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2025-04-08 to 2025-04-08
#
# Regime Distribution:
# Regime 0 [Bear]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2025-04-09 to 2025-04-09
#
# Regime Distribution:
# Regime 0 [Bear]: 100.00%
#
# Regime persistence: 1.00 days average duration
# Predicted regimes for period 2025-04-10 to 2025-04-10
#
# Regime Distribution:
# Regime 0 [Bear]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-01 to 2025-04-10 =====
# Training HMM model on data from 2019-01-01 to 2025-04-10
# Training data shape: (1578, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     946      0.12       17.39    2.83
# 1          Bear     72       -0.54      40.54    3.62
# 2          Neutral  560      0.04       22.96    3.10
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.96      0.00      0.04
# Bear      0.00      0.89      0.11
# Neutral   0.06      0.02      0.92
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 58.20%
# Regime 1 [Bear]: 5.41%
# Regime 2 [Neutral]: 36.39%
#
# ===== Rolling Window Simulation Complete =====
# Evaluated period: 2024-01-02 to 2025-04-10
# Total days evaluated: 320
# Number of model retrainings: 67
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 646
#     644 # Execute main function
#     645 if __name__ == "__main__":
# --> 646     model_objects = main()
#     648     # Example
#     649     # To analyze a custom period, uncomment and modify:
#     650     # custom_results = analyze_period(model_objects, "2008-01-01", "2009-12-31", "Market Regimes - 2008 Financial Crisis")
#
# Cell In[1], line 618, in main()
#     616 # Plot rolling window results
#     617 if rolling_results is not None:
# --> 618     plot_rolling_window_results(rolling_results)
#     620 return {
#     621     'model': model,
#     622     'data': df,
#    (...)
#     625     'rolling_results': rolling_results
#     626 }
#
# Cell In[1], line 540, in plot_rolling_window_results(results)
#     537 retrain_dates = results[results['Retrain_Event']]['Date'].unique()
#     538 for date in retrain_dates:
#     539     # Convert date to string format to avoid Timestamp arithmetic issues
# --> 540     fig.add_vline(x=date.strftime('%Y-%m-%d'), line_width=1, line_dash="dash", line_color="red",
#     541                   annotation_text="Retrain", annotation_position="top right")
#     543 # Update layout
#     544 fig.update_layout(
#     545     title=f'Rolling Window Regime Predictions ({results["Date"].min().strftime("%Y-%m-%d")} to {results["Date"].max().strftime("%Y-%m-%d")})',
#     546     xaxis_title='Date',
#    (...)
#     551     height=600
#     552 )
#
# File ~/miniconda3/envs/backtesting_env/lib/python3.9/site-packages/plotly/graph_objs/_figure.py:1049, in Figure.add_vline(self, x, row, col, exclude_empty_subplots, annotation, **kwargs)
#    1001 def add_vline(
#    1002     self,
#    1003     x,
#    (...)
#    1008     **kwargs,
#    1009 ) -> "Figure":
#    1010     """
#    1011
#    1012     Add a vertical line to a plot or subplot that extends infinitely in the
#    (...)
#    1047         except for x0, x1, y0, y1 or type.
#    1048     """
# -> 1049     return super(Figure, self).add_vline(
#    1050         x, row, col, exclude_empty_subplots, annotation, **kwargs
#    1051     )
#
# File ~/miniconda3/envs/backtesting_env/lib/python3.9/site-packages/plotly/basedatatypes.py:4095, in BaseFigure.add_vline(self, x, row, col, exclude_empty_subplots, annotation, **kwargs)
#    4086 def add_vline(
#    4087     self,
#    4088     x,
#    (...)
#    4093     **kwargs,
#    4094 ):
# -> 4095     self._process_multiple_axis_spanning_shapes(
#    4096         dict(type="line", x0=x, x1=x, y0=0, y1=1),
#    4097         row,
#    4098         col,
#    4099         "vline",
#    4100         exclude_empty_subplots=exclude_empty_subplots,
#    4101         annotation=annotation,
#    4102         **kwargs,
#    4103     )
#    4104     return self
#
# File ~/miniconda3/envs/backtesting_env/lib/python3.9/site-packages/plotly/basedatatypes.py:4036, in BaseFigure._process_multiple_axis_spanning_shapes(self, shape_args, row, col, shape_type, exclude_empty_subplots, annotation, **kwargs)
#    4027 # shapes are always added at the end of the tuple of shapes, so we see
#    4028 # how long the tuple is before the call and after the call, and adjust
#    4029 # the new shapes that were added at the end
#    4030 # extract annotation prefixed kwargs
#    4031 # annotation with extra parameters based on the annotation_position
#    4032 # argument and other annotation_ prefixed kwargs
#    4033 shape_kwargs, annotation_kwargs = shapeannotation.split_dict_by_key_prefix(
#    4034     kwargs, "annotation_"
#    4035 )
# -> 4036 augmented_annotation = shapeannotation.axis_spanning_shape_annotation(
#    4037     annotation, shape_type, shape_args, annotation_kwargs
#    4038 )
#    4039 self.add_shape(
#    4040     row=row,
#    4041     col=col,
#    4042     exclude_empty_subplots=exclude_empty_subplots,
#    4043     **_combine_dicts([shape_args, shape_kwargs]),
#    4044 )
#    4045 if augmented_annotation is not None:
#
# File ~/miniconda3/envs/backtesting_env/lib/python3.9/site-packages/plotly/shapeannotation.py:216, in axis_spanning_shape_annotation(annotation, shape_type, shape_args, kwargs)
#     214     annotation_position = kwargs["annotation_position"]
#     215 if shape_type.endswith("line"):
# --> 216     shape_dict = annotation_params_for_line(
#     217         shape_type, shape_args, annotation_position
#     218     )
#     219 elif shape_type.endswith("rect"):
#     220     shape_dict = annotation_params_for_rect(
#     221         shape_type, shape_args, annotation_position
#     222     )
#
# File ~/miniconda3/envs/backtesting_env/lib/python3.9/site-packages/plotly/shapeannotation.py:63, in annotation_params_for_line(shape_type, shape_args, position)
#      61 aX = max(X)
#      62 iX = min(X)
# ---> 63 eX = _mean(X)
#      64 aaX = _argmax(X)
#      65 aiX = _argmin(X)
#
# File ~/miniconda3/envs/backtesting_env/lib/python3.9/site-packages/plotly/shapeannotation.py:7, in _mean(x)
#       5 if len(x) == 0:
#       6     raise ValueError("x must have positive length")
# ----> 7 return float(sum(x)) / len(x)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
