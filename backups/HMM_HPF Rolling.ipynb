# %%
# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
from hmmlearn import hmm
import yfinance as yf
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# ======== CONFIGURABLE PARAMETERS ========
# Market data parameters
TICKER = 'SPY'  # Main ticker to analyze
VIX_TICKER = '^VIX'  # Volatility index
START_DATE = "2000-01-01"  # Historical data start date

# HMM model parameters  
HIDDEN_STATES = 3  # Number of market regimes
EM_ITERATIONS = 74  # Training iterations for HMM

# High-pass filter parameters
HPF_WINDOW = 10  #21 Window size for the high-pass filter moving average

# Training period
TRAIN_START_DATE = "2019-01-01"
TRAIN_END_DATE = "2024-01-01"

# Rolling window parameters
TRAINING_DELAY = 1  # Number of days to wait before retraining the model
USE_EXPANDING_WINDOW = False  # If True, use expanding window; if False, use fixed window

# ======== DATA PREPARATION FUNCTIONS ========
def download_market_data(ticker, vix_ticker, start_date):
    """Download and prepare market data"""
    end_date = datetime.today().strftime("%Y-%m-%d")
    print(f"Downloading market data from {start_date} to {end_date}...")
    
    # Download ticker and VIX data
    df_ticker = yf.download(ticker, start=start_date, end=end_date, auto_adjust=True)
    df_vix = yf.download(vix_ticker, start=start_date, end=end_date)
    
    # Fix column structure and reset index
    if len(df_ticker.columns.names) > 1:
        df_ticker.columns = df_ticker.columns.droplevel(1)
    if len(df_vix.columns.names) > 1:
        df_vix.columns = df_vix.columns.droplevel(1)
    
    df_ticker = df_ticker.reset_index()
    df_vix = df_vix.reset_index()
    
    # Keep only Date and Close from VIX
    df_vix = df_vix[['Date', 'Close']].rename(columns={'Close': 'VIX'})
    
    # Merge data
    df = pd.merge(df_ticker, df_vix, on='Date', how='left')
    df['VIX'] = df['VIX'].fillna(method='ffill')
    df['LogVIX'] = np.log(df['VIX'])
    
    return df

def calculate_indicators(data):
    """Calculate technical indicators for regime classification"""
    df_copy = data.copy()
    
    # Calculate returns
    df_copy['Return'] = df_copy['Close'].pct_change() * 100
    
    # Calculate volatility (10-day window)
    df_copy['MA10'] = df_copy['Close'].rolling(window=10).mean()
    df_copy['Volatility'] = df_copy['Close'].rolling(window=10).apply(
        lambda x: np.sum((x - x.mean())**2) / len(x)
    )
    
    # LogVIX ratio compared to 10-day average
    df_copy['LogVIX_10MA'] = df_copy['LogVIX'].rolling(window=10).mean()
    df_copy['LogVIX_Ratio'] = df_copy['LogVIX'] / df_copy['LogVIX_10MA']
    
    # Forward fill and backward fill any NaNs
    df_copy = df_copy.fillna(method='ffill').fillna(method='bfill')
    
    return df_copy

def apply_high_pass_filter(data, window_size=10):
    """
    Apply high-pass filter by subtracting moving average 
    from original signal to emphasize significant market movements
    """
    filtered_data = data.copy()
    
    # Apply HPF to returns
    filtered_data['Return_MA'] = filtered_data['Return'].rolling(window=window_size).mean()
    filtered_data['HPF_Return'] = filtered_data['Return'] - filtered_data['Return_MA']
    
    # Apply HPF to LogVIX
    filtered_data['LogVIX_MA'] = filtered_data['LogVIX'].rolling(window=window_size).mean()
    filtered_data['HPF_LogVIX'] = filtered_data['LogVIX'] - filtered_data['LogVIX_MA']
    
    # Apply HPF to volatility
    filtered_data['Volatility_MA'] = filtered_data['Volatility'].rolling(window=window_size).mean()
    filtered_data['HPF_Volatility'] = filtered_data['Volatility'] - filtered_data['Volatility_MA']
    
    # Fill any NaNs created by rolling windows
    filtered_data = filtered_data.fillna(method='ffill').fillna(method='bfill')
    
    return filtered_data

# ======== HMM MODEL FUNCTIONS ========
def train_hmm_model(data, start_date, end_date, n_states=3, n_iter=75):
    """Train HMM model on high-pass filtered features"""
    # Filter data to training period
    training = data[(data['Date'] >= start_date) & (data['Date'] <= end_date)].copy()
    
    print(f"Training HMM model on data from {start_date} to {end_date}")
    print(f"Training data shape: {training.shape}")
    
    # Prepare observations for HMM using HPF features
    obs = np.column_stack([
        training['HPF_Volatility'].values, 
        training['HPF_Return'].values,
        training['HPF_LogVIX'].values
    ])
    
    # Create and train the model
    model = hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=n_iter)
    model.fit(obs)
    
    # Get predictions for training data
    predictions = model.predict(obs)
    
    # Analyze regime characteristics using original (non-HPF) data for interpretability
    regime_stats = {}
    for i in range(n_states):
        regime_mask = (predictions == i)
        if np.sum(regime_mask) > 0:
            regime_stats[i] = {
                'count': np.sum(regime_mask),
                'return_avg': np.mean(training.loc[regime_mask, 'Return']),
                'vix_avg': np.mean(training.loc[regime_mask, 'VIX']),
                'logvix_avg': np.mean(training.loc[regime_mask, 'LogVIX']),
                'volatility_avg': np.mean(training.loc[regime_mask, 'Volatility'])
            }
    
    # Assign labels to regimes (Bull, Bear, Neutral) based on characteristics
    regime_labels = [""] * n_states
    bull_scores = []
    bear_scores = []
    neutral_scores = []
    
    for i in range(n_states):
        if i not in regime_stats:
            bull_scores.append(0)
            bear_scores.append(0)
            neutral_scores.append(0)
            continue
            
        stats = regime_stats[i]
        
        # Bull regime scoring: high returns, lower VIX
        bull_score = 0
        if stats['return_avg'] > 0.05:
            bull_score += 2
        elif stats['return_avg'] > 0:
            bull_score += 1
        
        if stats['logvix_avg'] < 2.8:  # Log(16.5) ≈ 2.8
            bull_score += 2
        elif stats['logvix_avg'] < 3.0:  # Log(20) ≈ 3.0
            bull_score += 1
        
        # Bear regime scoring: negative returns, higher VIX
        bear_score = 0
        if stats['return_avg'] < -0.1:
            bear_score += 2
        elif stats['return_avg'] < 0:
            bear_score += 1
        
        if stats['logvix_avg'] > 3.2:  # Log(25) ≈ 3.2
            bear_score += 2
        elif stats['logvix_avg'] > 3.0:
            bear_score += 1
        
        # Neutral regime scoring: modest returns, moderate VIX
        neutral_score = 0
        if -0.05 < stats['return_avg'] < 0.05:
            neutral_score += 2
        elif -0.1 < stats['return_avg'] < 0.1:
            neutral_score += 1
        
        if 2.8 <= stats['logvix_avg'] <= 3.2:
            neutral_score += 2
        elif 2.7 <= stats['logvix_avg'] <= 3.3:
            neutral_score += 1
        
        bull_scores.append(bull_score)
        bear_scores.append(bear_score)
        neutral_scores.append(neutral_score)
    
    # Assign labels based on highest score
    labels_to_assign = ["Bull", "Bear", "Neutral"]
    scores = [(i, max(bull_scores[i], bear_scores[i], neutral_scores[i]), 
               "Bull" if bull_scores[i] >= max(bear_scores[i], neutral_scores[i]) else
               "Bear" if bear_scores[i] >= max(bull_scores[i], neutral_scores[i]) else
               "Neutral") 
              for i in range(n_states)]
    
    # Sort by score and assign labels ensuring each label is used only once
    scores.sort(key=lambda x: x[1], reverse=True)
    assigned_labels = set()
    
    for regime_idx, _, preferred_label in scores:
        if preferred_label not in assigned_labels:
            regime_labels[regime_idx] = preferred_label
            assigned_labels.add(preferred_label)
        else:
            # Find an unassigned label
            for label in labels_to_assign:
                if label not in assigned_labels:
                    regime_labels[regime_idx] = label
                    assigned_labels.add(label)
                    break
    
    # Print key regime statistics
    print("\nRegime Characteristics Summary:")
    print("=" * 60)
    print(f"{'Regime':<10} {'Label':<8} {'Count':<8} {'Return %':<10} {'VIX':<8} {'LogVIX':<8}")
    print("-" * 60)
    
    for i in range(n_states):
        if i in regime_stats:
            stats = regime_stats[i]
            print(f"{i:<10} {regime_labels[i]:<8} {stats['count']:<8} "
                  f"{stats['return_avg']:<10.2f} {stats['vix_avg']:<8.2f} {stats['logvix_avg']:<8.2f}")
    
    # Print transition matrix
    print("\nRegime Transition Matrix:")
    transition_matrix = model.transmat_
    
    print("=" * 60)
    print(f"{'From/To':<10}", end="")
    for i in range(n_states):
        print(f"{regime_labels[i]:<10}", end="")
    print()
    print("-" * 60)
    
    for i in range(n_states):
        print(f"{regime_labels[i]:<10}", end="")
        for j in range(n_states):
            print(f"{transition_matrix[i, j]:<10.2f}", end="")
        print()
    
    # Calculate stationary distribution
    stationary_dist = model.get_stationary_distribution()
    print("\nStationary Distribution (Long-term regime probabilities):")
    for i in range(n_states):
        print(f"Regime {i} [{regime_labels[i]}]: {stationary_dist[i]*100:.2f}%")
    
    return model, training, predictions, regime_labels, regime_stats

def predict_regimes(model, data, start_date, end_date, regime_labels):
    """Predict market regimes for a specific date range using the trained HMM model"""
    # Filter data for prediction period
    pred_data = data[(data['Date'] >= start_date) & (data['Date'] <= end_date)].copy()
    
    if len(pred_data) == 0:
        print(f"No data available for period {start_date} to {end_date}")
        return None
    
    # Prepare observations for prediction using HPF features
    obs = np.column_stack([
        pred_data['HPF_Volatility'].values, 
        pred_data['HPF_Return'].values,
        pred_data['HPF_LogVIX'].values
    ])
    
    # Predict regimes
    predictions = model.predict(obs)
    
    # Add predictions to dataframe
    pred_data['Predicted_Regime'] = predictions
    pred_data['Regime_Label'] = [regime_labels[r] for r in predictions]
    
    # Print basic statistics about the prediction
    print(f"Predicted regimes for period {start_date} to {end_date}")
    
    # Calculate regime distribution
    regime_counts = pd.Series(predictions).value_counts(normalize=True) * 100
    print("\nRegime Distribution:")
    for regime, percentage in regime_counts.items():
        print(f"Regime {regime} [{regime_labels[regime]}]: {percentage:.2f}%")
    
    # Calculate average regime duration
    regime_changes = (pred_data['Predicted_Regime'] != pred_data['Predicted_Regime'].shift(1)).sum()
    avg_duration = len(pred_data) / (regime_changes if regime_changes > 0 else 1)
    print(f"\nRegime persistence: {avg_duration:.2f} days average duration")
    
    return pred_data

# ======== VISUALIZATION FUNCTIONS ========
def plot_regimes(results, title=None):
    """Plot SPY price with regime classifications"""
    if results is None or len(results) == 0:
        print("No data available to plot")
        return
    
    # Set plot title
    if title is None:
        start_date = results['Date'].min().strftime('%Y-%m-%d')
        end_date = results['Date'].max().strftime('%Y-%m-%d')
        title = f'Market Regimes from {start_date} to {end_date}'
    
    # Create a categorical color map for regimes
    unique_regimes = results['Predicted_Regime'].unique()
    n_regimes = len(unique_regimes)
    regime_colors = px.colors.qualitative.Set2[:n_regimes]
    
    # Create figure
    fig = go.Figure()
    
    # Add price line
    fig.add_trace(
        go.Scatter(
            x=results['Date'],
            y=results['Close'],
            mode='lines',
            line=dict(color='rgba(0,0,0,0.3)', width=1),
            name=f'{TICKER} Price'
        )
    )
    
    # Add colored markers for different regimes
    for i, regime in enumerate(sorted(unique_regimes)):
        regime_data = results[results['Predicted_Regime'] == regime]
        regime_label = results.loc[results['Predicted_Regime'] == regime, 'Regime_Label'].iloc[0]
        
        fig.add_trace(
            go.Scatter(
                x=regime_data['Date'], 
                y=regime_data['Close'],
                mode='markers',
                marker=dict(color=regime_colors[i], size=6),
                name=f'{regime_label} Regime',
                hovertemplate='%{x}<br>Price: %{y:.2f}<br>Regime: ' + regime_label
            )
        )
    
    # Update layout
    fig.update_layout(
        title=title,
        xaxis_title='Date',
        yaxis_title=f'{TICKER} Price',
        template='plotly_white',
        legend_title='Market Regimes',
        hovermode='closest',
        height=600
    )
    
    fig.show()
    
    # Create pie chart showing regime distribution
    regime_distribution = results['Regime_Label'].value_counts().reset_index()
    regime_distribution.columns = ['Regime', 'Days']
    regime_distribution['Percentage'] = regime_distribution['Days'] / len(results) * 100
    
    fig_pie = px.pie(
        regime_distribution, 
        values='Percentage', 
        names='Regime',
        title=f'Regime Distribution ({results["Date"].min().strftime("%Y-%m-%d")} to {results["Date"].max().strftime("%Y-%m-%d")})',
        color_discrete_sequence=regime_colors
    )
    
    fig_pie.update_traces(textinfo='percent+label', textposition='inside')
    fig_pie.update_layout(uniformtext_minsize=12, uniformtext_mode='hide')
    
    fig_pie.show()

# ======== ROLLING WINDOW FUNCTIONS ========
def run_rolling_window_simulation(df, initial_train_start, initial_train_end, 
                                 final_eval_date=None, training_delay=5, 
                                 use_expanding_window=True, n_states=3, n_iter=75):
    """
    Run a realistic rolling window simulation where the model is retrained periodically.
    
    Parameters:
    - df: DataFrame containing all market data
    - initial_train_start: Initial training period start date
    - initial_train_end: Initial training period end date
    - final_eval_date: Last date to evaluate (defaults to last date in dataset)
    - training_delay: Number of days to wait before retraining the model
    - use_expanding_window: If True, use expanding window; if False, use fixed window
    - n_states: Number of hidden states for HMM
    - n_iter: Number of EM iterations for HMM
    
    Returns:
    - DataFrame with regime predictions for the entire period
    """
    print(f"Running rolling window simulation with retraining every {training_delay} days")
    print(f"Using {'expanding' if use_expanding_window else 'fixed'} window approach")
    
    if final_eval_date is None:
        final_eval_date = df['Date'].max().strftime('%Y-%m-%d')
    
    # Convert dates to datetime objects for easier manipulation
    initial_train_start_dt = pd.to_datetime(initial_train_start)
    initial_train_end_dt = pd.to_datetime(initial_train_end)
    final_eval_date_dt = pd.to_datetime(final_eval_date)
    
    # Initialize the first model with the initial training period
    print(f"\n===== Initial Model Training: {initial_train_start} to {initial_train_end} =====")
    model, _, _, regime_labels, _ = train_hmm_model(
        df, initial_train_start, initial_train_end, n_states, n_iter
    )
    
    # Initialize variables to track our progress
    current_date = initial_train_end_dt
    next_retrain_date = current_date + timedelta(days=training_delay)
    current_train_start = initial_train_start_dt if use_expanding_window else initial_train_start_dt
    current_train_end = initial_train_end_dt
    
    # Create a results dataframe to store all predictions
    all_results = []
    
    # Variables to track retraining events
    retrain_dates = [initial_train_end_dt]
    
    # Sort dates for sequential processing
    all_dates = sorted(df['Date'].unique())
    all_dates = [date for date in all_dates if date >= initial_train_end_dt]
    
    # Loop through dates for evaluation
    for i in range(len(all_dates) - 1):
        current_date = all_dates[i]
        next_date = all_dates[i + 1]
        
        # Only predict one day at a time (current day)
        day_results = predict_regimes(
            model, df, 
            current_date.strftime('%Y-%m-%d'), 
            current_date.strftime('%Y-%m-%d'), 
            regime_labels
        )
        
        if day_results is not None:
            all_results.append(day_results)
        
        # Check if it's time to retrain the model
        if next_date >= next_retrain_date or next_date >= final_eval_date_dt:
            # Update the training window
            if use_expanding_window:
                # Expanding window keeps the same start date, but extends the end date
                current_train_end = current_date
            else:
                # Fixed window slides both start and end date
                window_size = (initial_train_end_dt - initial_train_start_dt).days
                current_train_start = current_date - timedelta(days=window_size)
                current_train_end = current_date
            
            print(f"\n===== Retraining Model: {current_train_start.strftime('%Y-%m-%d')} to {current_train_end.strftime('%Y-%m-%d')} =====")
            # Retrain the model
            model, _, _, regime_labels, _ = train_hmm_model(
                df, 
                current_train_start.strftime('%Y-%m-%d'), 
                current_train_end.strftime('%Y-%m-%d'), 
                n_states, n_iter
            )
            
            # Set the next retrain date
            next_retrain_date = next_date + timedelta(days=training_delay)
            retrain_dates.append(current_date)
        
        # Break the loop if we've reached the final evaluation date
        if current_date >= final_eval_date_dt:
            break
    
    # Combine all results
    if all_results:
        combined_results = pd.concat(all_results, ignore_index=True)
        combined_results = combined_results.sort_values('Date')
        
        # Create additional column to indicate model retraining dates
        combined_results['Retrain_Event'] = combined_results['Date'].isin(retrain_dates)
        
        print(f"\n===== Rolling Window Simulation Complete =====")
        print(f"Evaluated period: {combined_results['Date'].min().strftime('%Y-%m-%d')} to {combined_results['Date'].max().strftime('%Y-%m-%d')}")
        print(f"Total days evaluated: {len(combined_results)}")
        print(f"Number of model retrainings: {len(retrain_dates) - 1}")  # Subtract 1 for initial training
        
        return combined_results
    else:
        print("No results generated during simulation.")
        return None

def plot_rolling_window_results(results):
    """Plot the results of a rolling window simulation, highlighting retraining events"""
    if results is None or len(results) == 0:
        print("No data available to plot")
        return
    
    # Create a categorical color map for regimes
    unique_regimes = results['Predicted_Regime'].unique()
    n_regimes = len(unique_regimes)
    regime_colors = px.colors.qualitative.Set2[:n_regimes]
    
    # Create figure
    fig = go.Figure()
    
    # Add price line
    fig.add_trace(
        go.Scatter(
            x=results['Date'],
            y=results['Close'],
            mode='lines',
            line=dict(color='rgba(0,0,0,0.3)', width=1),
            name=f'{TICKER} Price'
        )
    )
    
    # Add colored markers for different regimes
    for i, regime in enumerate(sorted(unique_regimes)):
        regime_data = results[results['Predicted_Regime'] == regime]
        regime_label = results.loc[results['Predicted_Regime'] == regime, 'Regime_Label'].iloc[0]
        
        fig.add_trace(
            go.Scatter(
                x=regime_data['Date'], 
                y=regime_data['Close'],
                mode='markers',
                marker=dict(color=regime_colors[i], size=6),
                name=f'{regime_label} Regime',
                hovertemplate='%{x}<br>Price: %{y:.2f}<br>Regime: ' + regime_label
            )
        )
    
    # Add vertical lines for retraining events using scatter traces
    retrain_dates = results[results['Retrain_Event']]['Date'].unique()
    y_min = results['Close'].min() * 0.95  # Slightly below min price 
    y_max = results['Close'].max() * 1.05  # Slightly above max price

    for i, date in enumerate(retrain_dates):
        # Add a scatter trace with a vertical line
        fig.add_trace(
            go.Scatter(
                x=[date, date],
                y=[y_min, y_max],
                mode='lines',
                line=dict(color='red', width=1, dash='dash'),
                name='Retrain' if i == 0 else None,  # Only label the first one for legend
                showlegend=(i == 0),
                hoverinfo='none'
            )
        )
        
        # Add text annotation
        fig.add_annotation(
            x=date,
            y=y_max,
            text="Retrain",
            showarrow=False,
            yshift=10
        )
    
    # Update layout
    fig.update_layout(
        title=f'Rolling Window Regime Predictions ({results["Date"].min().strftime("%Y-%m-%d")} to {results["Date"].max().strftime("%Y-%m-%d")})',
        xaxis_title='Date',
        yaxis_title=f'{TICKER} Price',
        template='plotly_white',
        legend_title='Market Regimes',
        hovermode='closest',
        height=600
    )
    
    fig.show()
    
    # Create regime distribution by month or week
    results['YearMonth'] = results['Date'].dt.strftime('%Y-%m')
    monthly_regimes = results.groupby(['YearMonth', 'Regime_Label']).size().unstack().fillna(0)
    
    # Convert to percentages
    monthly_total = monthly_regimes.sum(axis=1)
    monthly_pct = monthly_regimes.div(monthly_total, axis=0) * 100
    
    # Plot monthly regime distribution
    fig_monthly = px.bar(
        monthly_pct.reset_index().melt(id_vars='YearMonth', var_name='Regime', value_name='Percentage'),
        x='YearMonth',
        y='Percentage',
        color='Regime',
        color_discrete_sequence=regime_colors,
        title='Monthly Regime Distribution',
        barmode='stack'
    )
    
    fig_monthly.update_layout(
        xaxis_title='Month',
        yaxis_title='Percentage (%)',
        legend_title='Regime',
        hovermode='x unified'
    )
    
    fig_monthly.show()


# ======== MAIN EXECUTION ========
def main():
    # Download and prepare data
    df = download_market_data(TICKER, VIX_TICKER, START_DATE)
    df = calculate_indicators(df)
    df = apply_high_pass_filter(df, HPF_WINDOW)
    
    # Train initial model
    model, training_data, train_predictions, regime_labels, regime_stats = train_hmm_model(
        df, TRAIN_START_DATE, TRAIN_END_DATE, HIDDEN_STATES, EM_ITERATIONS
    )
    
    # Plot training period results
    training_results = training_data.copy()
    training_results['Predicted_Regime'] = train_predictions
    training_results['Regime_Label'] = [regime_labels[r] for r in train_predictions]
    
    print("\nVisualization of training period regimes:")
    plot_regimes(training_results, f'Market Regimes - Training Period ({TRAIN_START_DATE} to {TRAIN_END_DATE})')
    
    # Run rolling window simulation
    rolling_results = run_rolling_window_simulation(
        df, 
        TRAIN_START_DATE, 
        TRAIN_END_DATE, 
        None,  # Use all available data
        TRAINING_DELAY,
        USE_EXPANDING_WINDOW,
        HIDDEN_STATES, 
        EM_ITERATIONS
    )
    
    # Plot rolling window results
    if rolling_results is not None:
        plot_rolling_window_results(rolling_results)
    
    return {
        'model': model,
        'data': df,
        'regime_labels': regime_labels,
        'training_results': training_results,
        'rolling_results': rolling_results
    }

# Function to analyze any time period
def analyze_period(model_objects, start_date, end_date, title=None):
    """Analyze any time period using the trained model"""
    results = predict_regimes(
        model_objects['model'], 
        model_objects['data'], 
        start_date, 
        end_date, 
        model_objects['regime_labels']
    )
    
    if results is not None:
        plot_regimes(results, title)
    
    return results

# Execute main function
if __name__ == "__main__":
    model_objects = main()
    
    # Example 
    # To analyze a custom period, uncomment and modify:
    # custom_results = analyze_period(model_objects, "2008-01-01", "2009-12-31", "Market Regimes - 2008 Financial Crisis")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Downloading market data from 2000-01-01 to 2025-04-14...
# Training HMM model on data from 2019-01-01 to 2024-01-01
# Training data shape: (1258, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Neutral  490      0.16       22.22    3.06
# 1          Bull     625      0.07       17.81    2.85
# 2          Bear     143      -0.28      34.00    3.47
#
# Regime Transition Matrix:
# ============================================================
# From/To   Neutral   Bull      Bear
# ------------------------------------------------------------
# Neutral   0.93      0.05      0.02
# Bull      0.03      0.95      0.02
# Bear      0.13      0.02      0.86
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Neutral]: 39.04%
# Regime 1 [Bull]: 49.49%
# Regime 2 [Bear]: 11.47%
#
# Visualization of training period regimes:
# Running rolling window simulation with retraining every 1 days
# Using fixed window approach
#
# ===== Initial Model Training: 2019-01-01 to 2024-01-01 =====
# Training HMM model on data from 2019-01-01 to 2024-01-01
# Training data shape: (1258, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     625      0.07       17.81    2.85
# 1          Bear     143      -0.28      34.00    3.47
# 2          Neutral  490      0.16       22.22    3.06
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.95      0.02      0.03
# Bear      0.02      0.86      0.13
# Neutral   0.05      0.02      0.93
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 49.48%
# Regime 1 [Bear]: 11.47%
# Regime 2 [Neutral]: 39.04%
# Predicted regimes for period 2024-01-02 to 2024-01-02
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-02 to 2024-01-02 =====
# Training HMM model on data from 2019-01-02 to 2024-01-02
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     625      0.07       17.81    2.85
# 1          Bear     143      -0.28      34.00    3.47
# 2          Neutral  491      0.16       22.20    3.06
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.95      0.02      0.03
# Bear      0.02      0.86      0.13
# Neutral   0.05      0.02      0.93
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 49.40%
# Regime 1 [Bear]: 11.47%
# Regime 2 [Neutral]: 39.13%
# Predicted regimes for period 2024-01-03 to 2024-01-03
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-03 to 2024-01-03 =====
# Training HMM model on data from 2019-01-03 to 2024-01-03
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     507      0.07       17.49    2.84
# 1          Bear     250      -0.16      30.96    3.38
# 2          Neutral  502      0.17       20.47    2.99
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.94      0.02      0.04
# Bear      0.01      0.91      0.08
# Neutral   0.06      0.02      0.92
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 40.58%
# Regime 1 [Bear]: 19.50%
# Regime 2 [Neutral]: 39.92%
# Predicted regimes for period 2024-01-04 to 2024-01-04
#
# Regime Distribution:
# Regime 1 [Bear]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-04 to 2024-01-04 =====
# Training HMM model on data from 2019-01-04 to 2024-01-04
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     507      0.07       17.49    2.84
# 1          Bear     249      -0.15      30.98    3.38
# 2          Neutral  503      0.17       20.46    2.99
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.94      0.02      0.04
# Bear      0.01      0.91      0.08
# Neutral   0.06      0.02      0.92
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 40.86%
# Regime 1 [Bear]: 19.39%
# Regime 2 [Neutral]: 39.75%
# Predicted regimes for period 2024-01-05 to 2024-01-05
#
# Regime Distribution:
# Regime 1 [Bear]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-05 to 2024-01-05 =====
# Training HMM model on data from 2019-01-05 to 2024-01-05
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     621      0.07       17.78    2.85
# 1          Neutral  494      0.16       22.14    3.06
# 2          Bear     144      -0.29      33.95    3.47
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Neutral   Bear
# ------------------------------------------------------------
# Bull      0.95      0.03      0.02
# Neutral   0.06      0.93      0.02
# Bear      0.02      0.12      0.86
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 49.82%
# Regime 1 [Neutral]: 38.51%
# Regime 2 [Bear]: 11.67%
# Predicted regimes for period 2024-01-08 to 2024-01-08
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-08 to 2024-01-08 =====
# Training HMM model on data from 2019-01-08 to 2024-01-08
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     498      0.18       20.48    2.99
# 1          Neutral  516      0.06       17.49    2.84
# 2          Bear     245      -0.18      31.14    3.39
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Neutral   Bear
# ------------------------------------------------------------
# Bull      0.92      0.06      0.02
# Neutral   0.04      0.94      0.02
# Bear      0.08      0.01      0.91
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 39.58%
# Regime 1 [Neutral]: 40.73%
# Regime 2 [Bear]: 19.69%
# Predicted regimes for period 2024-01-09 to 2024-01-09
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-09 to 2024-01-09 =====
# Training HMM model on data from 2019-01-09 to 2024-01-09
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     623      0.07       17.76    2.85
# 1          Bear     146      -0.27      33.81    3.47
# 2          Neutral  490      0.15       22.14    3.06
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.95      0.02      0.03
# Bear      0.02      0.86      0.12
# Neutral   0.06      0.02      0.92
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 49.64%
# Regime 1 [Bear]: 11.84%
# Regime 2 [Neutral]: 38.52%
# Predicted regimes for period 2024-01-10 to 2024-01-10
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-10 to 2024-01-10 =====
# Training HMM model on data from 2019-01-10 to 2024-01-10
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     618      0.08       17.71    2.85
# 1          Bear     145      -0.26      33.85    3.47
# 2          Neutral  496      0.15       22.15    3.06
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.95      0.02      0.03
# Bear      0.02      0.86      0.12
# Neutral   0.05      0.02      0.93
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 49.48%
# Regime 1 [Bear]: 11.83%
# Regime 2 [Neutral]: 38.69%
# Predicted regimes for period 2024-01-11 to 2024-01-11
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-11 to 2024-01-11 =====
# Training HMM model on data from 2019-01-11 to 2024-01-11
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     484      0.19       20.71    3.00
# 1          Bear     244      -0.18      31.15    3.39
# 2          Neutral  531      0.07       17.34    2.83
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.92      0.02      0.06
# Bear      0.09      0.91      0.00
# Neutral   0.04      0.02      0.94
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 38.33%
# Regime 1 [Bear]: 19.68%
# Regime 2 [Neutral]: 41.98%
# Predicted regimes for period 2024-01-12 to 2024-01-12
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-12 to 2024-01-12 =====
# Training HMM model on data from 2019-01-12 to 2024-01-12
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Neutral  493      0.15       22.13    3.06
# 1          Bear     146      -0.27      33.81    3.47
# 2          Bull     620      0.07       17.72    2.85
#
# Regime Transition Matrix:
# ============================================================
# From/To   Neutral   Bear      Bull
# ------------------------------------------------------------
# Neutral   0.93      0.02      0.05
# Bear      0.12      0.86      0.02
# Bull      0.03      0.02      0.95
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Neutral]: 38.83%
# Regime 1 [Bear]: 11.90%
# Regime 2 [Bull]: 49.27%
# Predicted regimes for period 2024-01-16 to 2024-01-16
#
# Regime Distribution:
# Regime 2 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-16 to 2024-01-16 =====
# Training HMM model on data from 2019-01-16 to 2024-01-16
# Training data shape: (1258, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     510      0.07       17.43    2.83
# 1          Neutral  503      0.17       20.45    2.99
# 2          Bear     245      -0.18      31.14    3.39
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Neutral   Bear
# ------------------------------------------------------------
# Bull      0.94      0.04      0.02
# Neutral   0.06      0.92      0.02
# Bear      0.01      0.08      0.91
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 41.75%
# Regime 1 [Neutral]: 38.47%
# Regime 2 [Bear]: 19.78%
# Predicted regimes for period 2024-01-17 to 2024-01-17
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-17 to 2024-01-17 =====
# Training HMM model on data from 2019-01-17 to 2024-01-17
# Training data shape: (1258, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     619      0.07       17.70    2.85
# 1          Bear     146      -0.27      33.81    3.47
# 2          Neutral  493      0.15       22.13    3.06
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.95      0.02      0.03
# Bear      0.02      0.86      0.12
# Neutral   0.05      0.02      0.93
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 49.21%
# Regime 1 [Bear]: 11.91%
# Regime 2 [Neutral]: 38.87%
# Predicted regimes for period 2024-01-18 to 2024-01-18
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-18 to 2024-01-18 =====
# Training HMM model on data from 2019-01-18 to 2024-01-18
# Training data shape: (1258, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     564      0.07       17.64    2.84
# 1          Bear     224      -0.28      31.31    3.39
# 2          Neutral  470      0.22       20.93    3.00
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.95      0.02      0.03
# Bear      0.01      0.89      0.10
# Neutral   0.06      0.03      0.91
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 44.31%
# Regime 1 [Bear]: 18.09%
# Regime 2 [Neutral]: 37.60%
# Predicted regimes for period 2024-01-19 to 2024-01-19
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-19 to 2024-01-19 =====
# Training HMM model on data from 2019-01-19 to 2024-01-19
# Training data shape: (1258, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     564      0.07       17.63    2.84
# 1          Neutral  470      0.22       20.93    3.00
# 2          Bear     224      -0.28      31.31    3.39
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Neutral   Bear
# ------------------------------------------------------------
# Bull      0.95      0.03      0.02
# Neutral   0.06      0.91      0.03
# Bear      0.01      0.10      0.89
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 44.19%
# Regime 1 [Neutral]: 37.70%
# Regime 2 [Bear]: 18.10%
# Predicted regimes for period 2024-01-22 to 2024-01-22
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-22 to 2024-01-22 =====
# Training HMM model on data from 2019-01-22 to 2024-01-22
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     565      0.07       17.62    2.84
# 1          Bear     224      -0.28      31.31    3.39
# 2          Neutral  470      0.22       20.93    3.00
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.95      0.02      0.03
# Bear      0.01      0.89      0.10
# Neutral   0.06      0.03      0.91
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 44.21%
# Regime 1 [Bear]: 18.10%
# Regime 2 [Neutral]: 37.69%
# Predicted regimes for period 2024-01-23 to 2024-01-23
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-23 to 2024-01-23 =====
# Training HMM model on data from 2019-01-23 to 2024-01-23
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     565      0.07       17.61    2.84
# 1          Bear     224      -0.28      31.31    3.39
# 2          Neutral  470      0.22       20.93    3.00
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.95      0.02      0.03
# Bear      0.01      0.89      0.10
# Neutral   0.06      0.03      0.91
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 44.09%
# Regime 1 [Bear]: 18.12%
# Regime 2 [Neutral]: 37.79%
# Predicted regimes for period 2024-01-24 to 2024-01-24
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-24 to 2024-01-24 =====
# Training HMM model on data from 2019-01-24 to 2024-01-24
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     536      0.08       17.36    2.83
# 1          Bear     244      -0.18      31.15    3.39
# 2          Neutral  479      0.18       20.64    2.99
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.95      0.02      0.03
# Bear      0.01      0.91      0.08
# Neutral   0.06      0.02      0.92
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 42.35%
# Regime 1 [Bear]: 19.63%
# Regime 2 [Neutral]: 38.03%
# Predicted regimes for period 2024-01-25 to 2024-01-25
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-25 to 2024-01-25 =====
# Training HMM model on data from 2019-01-25 to 2024-01-25
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Neutral  686      0.03       18.22    2.87
# 1          Bear     238      -0.14      30.60    3.36
# 2          Bull     335      0.28       20.92    3.01
#
# Regime Transition Matrix:
# ============================================================
# From/To   Neutral   Bear      Bull
# ------------------------------------------------------------
# Neutral   0.81      0.03      0.16
# Bear      0.00      0.91      0.09
# Bull      0.33      0.00      0.67
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Neutral]: 51.10%
# Regime 1 [Bear]: 19.50%
# Regime 2 [Bull]: 29.40%
# Predicted regimes for period 2024-01-26 to 2024-01-26
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-26 to 2024-01-26 =====
# Training HMM model on data from 2019-01-26 to 2024-01-26
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     500      0.17       20.42    2.98
# 1          Neutral  514      0.08       17.39    2.83
# 2          Bear     245      -0.18      31.14    3.39
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Neutral   Bear
# ------------------------------------------------------------
# Bull      0.92      0.06      0.02
# Neutral   0.04      0.94      0.02
# Bear      0.08      0.01      0.91
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 38.80%
# Regime 1 [Neutral]: 41.53%
# Regime 2 [Bear]: 19.67%
# Predicted regimes for period 2024-01-29 to 2024-01-29
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-29 to 2024-01-29 =====
# Training HMM model on data from 2019-01-29 to 2024-01-29
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     481      0.18       20.58    2.99
# 1          Neutral  533      0.08       17.35    2.83
# 2          Bear     245      -0.18      31.14    3.39
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Neutral   Bear
# ------------------------------------------------------------
# Bull      0.92      0.06      0.02
# Neutral   0.04      0.94      0.02
# Bear      0.08      0.00      0.91
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 39.13%
# Regime 1 [Neutral]: 41.23%
# Regime 2 [Bear]: 19.64%
# Predicted regimes for period 2024-01-30 to 2024-01-30
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-30 to 2024-01-30 =====
# Training HMM model on data from 2019-01-30 to 2024-01-30
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     558      0.07       17.60    2.84
# 1          Bear     224      -0.28      31.31    3.39
# 2          Neutral  477      0.22       20.83    3.00
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.94      0.02      0.04
# Bear      0.01      0.89      0.10
# Neutral   0.06      0.03      0.92
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 42.82%
# Regime 1 [Bear]: 18.12%
# Regime 2 [Neutral]: 39.07%
# Predicted regimes for period 2024-01-31 to 2024-01-31
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-01-31 to 2024-01-31 =====
# Training HMM model on data from 2019-01-31 to 2024-01-31
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     528      0.08       17.35    2.83
# 1          Bear     245      -0.18      31.14    3.39
# 2          Neutral  486      0.17       20.53    2.99
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.94      0.02      0.04
# Bear      0.01      0.91      0.08
# Neutral   0.06      0.02      0.92
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 41.11%
# Regime 1 [Bear]: 19.60%
# Regime 2 [Neutral]: 39.29%
# Predicted regimes for period 2024-02-01 to 2024-02-01
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-02-01 to 2024-02-01 =====
# Training HMM model on data from 2019-02-01 to 2024-02-01
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     556      0.07       17.60    2.84
# 1          Bear     224      -0.28      31.31    3.39
# 2          Neutral  479      0.22       20.80    3.00
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.94      0.02      0.04
# Bear      0.01      0.89      0.10
# Neutral   0.06      0.03      0.92
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 42.63%
# Regime 1 [Bear]: 18.07%
# Regime 2 [Neutral]: 39.30%
# Predicted regimes for period 2024-02-02 to 2024-02-02
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-02-02 to 2024-02-02 =====
# Training HMM model on data from 2019-02-02 to 2024-02-02
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     555      0.07       17.60    2.84
# 1          Bear     224      -0.28      31.31    3.39
# 2          Neutral  480      0.22       20.79    3.00
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.94      0.02      0.04
# Bear      0.01      0.89      0.10
# Neutral   0.06      0.03      0.92
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 42.55%
# Regime 1 [Bear]: 18.06%
# Regime 2 [Neutral]: 39.39%
# Predicted regimes for period 2024-02-05 to 2024-02-05
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-02-05 to 2024-02-05 =====
# Training HMM model on data from 2019-02-05 to 2024-02-05
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     554      0.07       17.61    2.84
# 1          Bear     224      -0.28      31.31    3.39
# 2          Neutral  481      0.22       20.77    3.00
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.94      0.02      0.04
# Bear      0.01      0.89      0.10
# Neutral   0.06      0.03      0.92
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 42.46%
# Regime 1 [Bear]: 18.06%
# Regime 2 [Neutral]: 39.48%
# Predicted regimes for period 2024-02-06 to 2024-02-06
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-02-06 to 2024-02-06 =====
# Training HMM model on data from 2019-02-06 to 2024-02-06
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     553      0.07       17.61    2.84
# 1          Bear     224      -0.28      31.31    3.39
# 2          Neutral  482      0.22       20.76    3.00
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.94      0.02      0.04
# Bear      0.01      0.89      0.10
# Neutral   0.06      0.03      0.92
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 42.33%
# Regime 1 [Bear]: 18.09%
# Regime 2 [Neutral]: 39.58%
# Predicted regimes for period 2024-02-07 to 2024-02-07
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-02-07 to 2024-02-07 =====
# Training HMM model on data from 2019-02-07 to 2024-02-07
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     483      0.22       20.74    2.99
# 1          Neutral  552      0.07       17.62    2.84
# 2          Bear     224      -0.28      31.31    3.39
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Neutral   Bear
# ------------------------------------------------------------
# Bull      0.92      0.06      0.03
# Neutral   0.04      0.94      0.02
# Bear      0.10      0.01      0.89
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 39.62%
# Regime 1 [Neutral]: 42.27%
# Regime 2 [Bear]: 18.10%
# Predicted regimes for period 2024-02-08 to 2024-02-08
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-02-08 to 2024-02-08 =====
# Training HMM model on data from 2019-02-08 to 2024-02-08
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     551      0.07       17.62    2.84
# 1          Bear     224      -0.28      31.31    3.39
# 2          Neutral  484      0.22       20.72    2.99
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.94      0.02      0.04
# Bear      0.01      0.89      0.10
# Neutral   0.06      0.03      0.92
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 42.38%
# Regime 1 [Bear]: 18.10%
# Regime 2 [Neutral]: 39.52%
# Predicted regimes for period 2024-02-09 to 2024-02-09
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-02-09 to 2024-02-09 =====
# Training HMM model on data from 2019-02-09 to 2024-02-09
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     550      0.07       17.62    2.84
# 1          Bear     224      -0.28      31.31    3.39
# 2          Neutral  485      0.22       20.71    2.99
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.94      0.02      0.04
# Bear      0.01      0.89      0.10
# Neutral   0.06      0.03      0.92
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 42.51%
# Regime 1 [Bear]: 18.08%
# Regime 2 [Neutral]: 39.40%
# Predicted regimes for period 2024-02-12 to 2024-02-12
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-02-12 to 2024-02-12 =====
# Training HMM model on data from 2019-02-12 to 2024-02-12
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     549      0.07       17.62    2.84
# 1          Bear     224      -0.28      31.31    3.39
# 2          Neutral  486      0.22       20.69    2.99
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.94      0.02      0.04
# Bear      0.01      0.89      0.10
# Neutral   0.06      0.03      0.92
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 42.51%
# Regime 1 [Bear]: 18.06%
# Regime 2 [Neutral]: 39.43%
# Predicted regimes for period 2024-02-13 to 2024-02-13
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-02-13 to 2024-02-13 =====
# Training HMM model on data from 2019-02-13 to 2024-02-13
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     493      0.17       20.43    2.98
# 1          Neutral  521      0.08       17.36    2.83
# 2          Bear     245      -0.18      31.14    3.39
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Neutral   Bear
# ------------------------------------------------------------
# Bull      0.92      0.06      0.02
# Neutral   0.04      0.94      0.02
# Bear      0.08      0.01      0.91
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 39.55%
# Regime 1 [Neutral]: 40.85%
# Regime 2 [Bear]: 19.60%
# Predicted regimes for period 2024-02-14 to 2024-02-14
#
# Regime Distribution:
# Regime 1 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-02-14 to 2024-02-14 =====
# Training HMM model on data from 2019-02-14 to 2024-02-14
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     482      0.22       20.76    3.00
# 1          Bear     224      -0.28      31.31    3.39
# 2          Neutral  553      0.07       17.59    2.84
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.91      0.03      0.06
# Bear      0.10      0.89      0.01
# Neutral   0.04      0.02      0.94
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 38.90%
# Regime 1 [Bear]: 17.98%
# Regime 2 [Neutral]: 43.12%
# Predicted regimes for period 2024-02-15 to 2024-02-15
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-02-15 to 2024-02-15 =====
# Training HMM model on data from 2019-02-15 to 2024-02-15
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     493      0.17       20.43    2.98
# 1          Bear     245      -0.18      31.14    3.39
# 2          Neutral  521      0.08       17.36    2.83
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.92      0.02      0.06
# Bear      0.08      0.91      0.01
# Neutral   0.04      0.02      0.94
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 39.43%
# Regime 1 [Bear]: 19.55%
# Regime 2 [Neutral]: 41.03%
# Predicted regimes for period 2024-02-16 to 2024-02-16
#
# Regime Distribution:
# Regime 2 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-02-16 to 2024-02-16 =====
# Training HMM model on data from 2019-02-16 to 2024-02-16
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     555      0.07       17.58    2.84
# 1          Bear     224      -0.28      31.31    3.39
# 2          Neutral  480      0.22       20.78    3.00
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.94      0.02      0.04
# Bear      0.01      0.89      0.10
# Neutral   0.06      0.03      0.91
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 43.20%
# Regime 1 [Bear]: 17.97%
# Regime 2 [Neutral]: 38.83%
# Predicted regimes for period 2024-02-20 to 2024-02-20
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-02-20 to 2024-02-20 =====
# Training HMM model on data from 2019-02-20 to 2024-02-20
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     707      0.06       17.79    2.85
# 1          Bear     140      -0.32      34.57    3.48
# 2          Neutral  412      0.19       22.64    3.09
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.96      0.02      0.02
# Bear      0.02      0.86      0.12
# Neutral   0.06      0.02      0.93
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 54.94%
# Regime 1 [Bear]: 11.44%
# Regime 2 [Neutral]: 33.62%
# Predicted regimes for period 2024-02-21 to 2024-02-21
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-02-21 to 2024-02-21 =====
# Training HMM model on data from 2019-02-21 to 2024-02-21
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Neutral  411      0.19       22.65    3.09
# 1          Bull     708      0.06       17.79    2.85
# 2          Bear     140      -0.32      34.57    3.48
#
# Regime Transition Matrix:
# ============================================================
# From/To   Neutral   Bull      Bear
# ------------------------------------------------------------
# Neutral   0.93      0.06      0.02
# Bull      0.02      0.96      0.02
# Bear      0.12      0.02      0.86
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Neutral]: 33.09%
# Regime 1 [Bull]: 55.47%
# Regime 2 [Bear]: 11.44%
# Predicted regimes for period 2024-02-22 to 2024-02-22
#
# Regime Distribution:
# Regime 1 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-02-22 to 2024-02-22 =====
# Training HMM model on data from 2019-02-22 to 2024-02-22
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     510      0.08       17.43    2.83
# 1          Bear     245      -0.18      31.14    3.39
# 2          Neutral  504      0.17       20.29    2.98
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.94      0.02      0.04
# Bear      0.00      0.91      0.09
# Neutral   0.06      0.02      0.92
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 39.68%
# Regime 1 [Bear]: 19.53%
# Regime 2 [Neutral]: 40.78%
# Predicted regimes for period 2024-02-23 to 2024-02-23
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-02-23 to 2024-02-23 =====
# Training HMM model on data from 2019-02-23 to 2024-02-23
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     709      0.07       17.80    2.85
# 1          Bear     140      -0.32      34.57    3.48
# 2          Neutral  410      0.19       22.65    3.09
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.96      0.02      0.02
# Bear      0.02      0.86      0.12
# Neutral   0.06      0.02      0.93
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 55.70%
# Regime 1 [Bear]: 11.44%
# Regime 2 [Neutral]: 32.86%
# Predicted regimes for period 2024-02-26 to 2024-02-26
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-02-26 to 2024-02-26 =====
# Training HMM model on data from 2019-02-26 to 2024-02-26
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Neutral  232      -0.02      22.70    3.09
# 1          Bear     207      -0.09      31.49    3.40
# 2          Bull     820      0.13       18.24    2.87
#
# Regime Transition Matrix:
# ============================================================
# From/To   Neutral   Bear      Bull
# ------------------------------------------------------------
# Neutral   0.81      0.03      0.15
# Bear      0.00      0.94      0.06
# Bull      0.06      0.00      0.93
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Neutral]: 21.32%
# Regime 1 [Bear]: 16.30%
# Regime 2 [Bull]: 62.38%
# Predicted regimes for period 2024-02-27 to 2024-02-27
#
# Regime Distribution:
# Regime 2 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-02-27 to 2024-02-27 =====
# Training HMM model on data from 2019-02-27 to 2024-02-27
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Neutral  235      -0.02      22.62    3.09
# 1          Bear     204      -0.08      31.46    3.39
# 2          Bull     820      0.12       18.31    2.87
#
# Regime Transition Matrix:
# ============================================================
# From/To   Neutral   Bear      Bull
# ------------------------------------------------------------
# Neutral   0.81      0.03      0.16
# Bear      0.00      0.94      0.06
# Bull      0.06      0.00      0.93
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Neutral]: 21.30%
# Regime 1 [Bear]: 16.28%
# Regime 2 [Bull]: 62.42%
# Predicted regimes for period 2024-02-28 to 2024-02-28
#
# Regime Distribution:
# Regime 2 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-02-28 to 2024-02-28 =====
# Training HMM model on data from 2019-02-28 to 2024-02-28
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     698      0.10       18.53    2.89
# 1          Bear     286      0.10       19.95    2.96
# 2          Neutral  275      -0.07      29.47    3.32
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.91      0.06      0.04
# Bear      0.15      0.83      0.02
# Neutral   0.06      0.04      0.90
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 53.41%
# Regime 1 [Bear]: 24.07%
# Regime 2 [Neutral]: 22.51%
# Predicted regimes for period 2024-02-29 to 2024-02-29
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-03-01 to 2024-02-29 =====
# Training HMM model on data from 2019-03-01 to 2024-02-29
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     709      0.07       17.79    2.85
# ...
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-04-25 to 2024-04-24 =====
# Training HMM model on data from 2019-04-25 to 2024-04-24
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Neutral  405      0.20       22.46    3.08
# 1          Bull     700      0.07       17.82    2.85
# 2          Bear     154      -0.34      33.87    3.46
#
# Regime Transition Matrix:
# ============================================================
# From/To   Neutral   Bull      Bear
# ------------------------------------------------------------
# Neutral   0.93      0.06      0.02
# Bull      0.02      0.96      0.02
# Bear      0.12      0.03      0.86
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Neutral]: 32.43%
# Regime 1 [Bull]: 55.59%
# Regime 2 [Bear]: 11.98%
# Predicted regimes for period 2024-04-25 to 2024-04-25
#
# Regime Distribution:
# Regime 1 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-04-26 to 2024-04-25 =====
# Training HMM model on data from 2019-04-26 to 2024-04-25
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Neutral  416      0.19       22.65    3.09
# 1          Bear     147      -0.34      34.08    3.47
# 2          Bull     696      0.07       17.75    2.85
#
# Regime Transition Matrix:
# ============================================================
# From/To   Neutral   Bear      Bull
# ------------------------------------------------------------
# Neutral   0.93      0.01      0.06
# Bear      0.14      0.86      0.00
# Bull      0.02      0.02      0.96
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Neutral]: 33.69%
# Regime 1 [Bear]: 11.76%
# Regime 2 [Bull]: 54.55%
# Predicted regimes for period 2024-04-26 to 2024-04-26
#
# Regime Distribution:
# Regime 2 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-04-27 to 2024-04-26 =====
# Training HMM model on data from 2019-04-27 to 2024-04-26
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     698      0.07       17.83    2.85
# 1          Bear     154      -0.34      33.87    3.46
# 2          Neutral  407      0.20       22.43    3.08
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.96      0.02      0.02
# Bear      0.03      0.86      0.12
# Neutral   0.06      0.02      0.93
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 55.32%
# Regime 1 [Bear]: 12.02%
# Regime 2 [Neutral]: 32.66%
# Predicted regimes for period 2024-04-29 to 2024-04-29
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-04-30 to 2024-04-29 =====
# Training HMM model on data from 2019-04-30 to 2024-04-29
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     697      0.07       17.84    2.85
# 1          Neutral  408      0.20       22.41    3.08
# 2          Bear     154      -0.34      33.87    3.46
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Neutral   Bear
# ------------------------------------------------------------
# Bull      0.96      0.02      0.02
# Neutral   0.06      0.93      0.02
# Bear      0.03      0.12      0.86
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 55.32%
# Regime 1 [Neutral]: 32.64%
# Regime 2 [Bear]: 12.04%
# Predicted regimes for period 2024-04-30 to 2024-04-30
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-05-01 to 2024-04-30 =====
# Training HMM model on data from 2019-05-01 to 2024-04-30
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     696      0.07       17.85    2.85
# 1          Bear     154      -0.34      33.87    3.46
# 2          Neutral  409      0.19       22.39    3.08
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.96      0.02      0.02
# Bear      0.03      0.86      0.12
# Neutral   0.06      0.02      0.93
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 55.26%
# Regime 1 [Bear]: 12.03%
# Regime 2 [Neutral]: 32.70%
# Predicted regimes for period 2024-05-01 to 2024-05-01
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-05-02 to 2024-05-01 =====
# Training HMM model on data from 2019-05-02 to 2024-05-01
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     487      0.05       17.76    2.85
# 1          Bear     247      -0.18      30.94    3.38
# 2          Neutral  525      0.18       20.01    2.96
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.93      0.03      0.05
# Bear      0.01      0.91      0.08
# Neutral   0.06      0.02      0.92
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 38.20%
# Regime 1 [Bear]: 19.88%
# Regime 2 [Neutral]: 41.92%
# Predicted regimes for period 2024-05-02 to 2024-05-02
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-05-03 to 2024-05-02 =====
# Training HMM model on data from 2019-05-03 to 2024-05-02
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     694      0.07       17.85    2.85
# 1          Bear     154      -0.34      33.87    3.46
# 2          Neutral  411      0.19       22.36    3.07
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.96      0.02      0.02
# Bear      0.02      0.86      0.12
# Neutral   0.06      0.02      0.93
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 55.10%
# Regime 1 [Bear]: 12.04%
# Regime 2 [Neutral]: 32.86%
# Predicted regimes for period 2024-05-03 to 2024-05-03
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-05-04 to 2024-05-03 =====
# Training HMM model on data from 2019-05-04 to 2024-05-03
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     689      0.07       17.79    2.85
# 1          Bear     148      -0.35      34.00    3.47
# 2          Neutral  422      0.19       22.53    3.08
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.96      0.02      0.01
# Bear      0.00      0.86      0.14
# Neutral   0.06      0.01      0.93
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 54.32%
# Regime 1 [Bear]: 11.87%
# Regime 2 [Neutral]: 33.81%
# Predicted regimes for period 2024-05-06 to 2024-05-06
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-05-07 to 2024-05-06 =====
# Training HMM model on data from 2019-05-07 to 2024-05-06
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     688      0.07       17.86    2.85
# 1          Bear     159      -0.35      33.39    3.45
# 2          Neutral  412      0.20       22.33    3.07
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.96      0.02      0.02
# Bear      0.04      0.85      0.11
# Neutral   0.06      0.02      0.93
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 56.16%
# Regime 1 [Bear]: 12.05%
# Regime 2 [Neutral]: 31.80%
# Predicted regimes for period 2024-05-07 to 2024-05-07
#
# Regime Distribution:
# Regime 1 [Bear]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-05-08 to 2024-05-07 =====
# Training HMM model on data from 2019-05-08 to 2024-05-07
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     689      0.07       17.86    2.85
# 1          Bear     157      -0.36      33.61    3.45
# 2          Neutral  413      0.20       22.28    3.07
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.96      0.02      0.02
# Bear      0.02      0.86      0.12
# Neutral   0.06      0.02      0.93
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 55.04%
# Regime 1 [Bear]: 12.19%
# Regime 2 [Neutral]: 32.77%
# Predicted regimes for period 2024-05-08 to 2024-05-08
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-05-09 to 2024-05-08 =====
# Training HMM model on data from 2019-05-09 to 2024-05-08
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Neutral  480      0.05       17.76    2.85
# 1          Bear     249      -0.18      30.90    3.38
# 2          Bull     530      0.19       19.94    2.96
#
# Regime Transition Matrix:
# ============================================================
# From/To   Neutral   Bear      Bull
# ------------------------------------------------------------
# Neutral   0.93      0.03      0.05
# Bear      0.01      0.91      0.08
# Bull      0.06      0.02      0.92
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Neutral]: 38.39%
# Regime 1 [Bear]: 19.90%
# Regime 2 [Bull]: 41.72%
# Predicted regimes for period 2024-05-09 to 2024-05-09
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-05-10 to 2024-05-09 =====
# Training HMM model on data from 2019-05-10 to 2024-05-09
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     688      0.07       17.86    2.85
# 1          Bear     157      -0.36      33.61    3.45
# 2          Neutral  414      0.20       22.25    3.07
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.96      0.02      0.02
# Bear      0.03      0.86      0.11
# Neutral   0.06      0.02      0.93
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 55.00%
# Regime 1 [Bear]: 12.47%
# Regime 2 [Neutral]: 32.52%
# Predicted regimes for period 2024-05-10 to 2024-05-10
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-05-11 to 2024-05-10 =====
# Training HMM model on data from 2019-05-11 to 2024-05-10
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Neutral  264      0.02       23.58    3.13
# 1          Bear     140      -0.21      33.66    3.45
# 2          Bull     855      0.12       18.52    2.89
#
# Regime Transition Matrix:
# ============================================================
# From/To   Neutral   Bear      Bull
# ------------------------------------------------------------
# Neutral   0.82      0.04      0.15
# Bear      0.03      0.90      0.06
# Bull      0.06      0.00      0.94
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Neutral]: 22.11%
# Regime 1 [Bear]: 11.20%
# Regime 2 [Bull]: 66.68%
# Predicted regimes for period 2024-05-13 to 2024-05-13
#
# Regime Distribution:
# Regime 0 [Neutral]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-05-14 to 2024-05-13 =====
# Training HMM model on data from 2019-05-14 to 2024-05-13
# Training data shape: (1259, 19)
#
# Regime Characteristics Summary:
# ============================================================
# Regime     Label    Count    Return %   VIX      LogVIX
# ------------------------------------------------------------
# 0          Bull     686      0.08       17.86    2.85
# 1          Bear     157      -0.36      33.61    3.45
# 2          Neutral  416      0.20       22.21    3.07
#
# Regime Transition Matrix:
# ============================================================
# From/To   Bull      Bear      Neutral
# ------------------------------------------------------------
# Bull      0.96      0.02      0.02
# Bear      0.03      0.86      0.11
# Neutral   0.06      0.02      0.93
#
# Stationary Distribution (Long-term regime probabilities):
# Regime 0 [Bull]: 54.72%
# Regime 1 [Bear]: 12.54%
# Regime 2 [Neutral]: 32.73%
# Predicted regimes for period 2024-05-14 to 2024-05-14
#
# Regime Distribution:
# Regime 0 [Bull]: 100.00%
#
# Regime persistence: 1.00 days average duration
#
# ===== Retraining Model: 2019-05-15 to 2024-05-14 =====
# Training HMM model on data from 2019-05-15 to 2024-05-14
# Training data shape: (1259, 19)
